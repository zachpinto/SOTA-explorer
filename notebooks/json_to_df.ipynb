# %%
import os
import json
import pandas as pd

# %%
DATA_DIR = '../data/raw'

# %% [markdown]
# Dataframe 1: Tasks by Area

# %%
# Step 1: Load tasks by area
tasks_data = []

for file in os.listdir(DATA_DIR):
    if file.startswith('tasks_') and file.endswith('.json'):
        area = file[len('tasks_'):-len('.json')]
        with open(os.path.join(DATA_DIR, file), 'r') as f:
            tasks = json.load(f)
            for task in tasks:
                tasks_data.append({
                    'area': area,
                    'id': task['id'],
                    'name': task['name'],
                    'description': task['description'],
                    'children': '',
                    'parents': '',
                    'num_evals': 0
                })

tasks_df = pd.DataFrame(tasks_data)
print("Tasks by Area DataFrame:")
tasks_df
# Out:
# Tasks by Area DataFrame:
#                              area                                        id  \
# 0                     methodology  depth-anomaly-detection-and-segmentation
# 1                     methodology                     stroke-classification
# 2                     methodology                neural-network-compression
# 3                     methodology           transfer-reinforcement-learning
# 4                     methodology                        variable-selection
# ...                           ...                                       ...
# 3490  natural-language-processing                    nonsense-words-grammar
# 3491  natural-language-processing             multimodal-sentiment-analysis
# 3492  natural-language-processing            task-oriented-dialogue-systems
# 3493  natural-language-processing                       dialogue-management
# 3494  natural-language-processing                                  arqmath2
#
#                                           name  \
# 0     Depth Anomaly Detection and Segmentation
# 1                        Stroke Classification
# 2                   Neural Network Compression
# 3              Transfer Reinforcement Learning
# 4                           Variable Selection
# ...                                        ...
# 3490                    Nonsense Words Grammar
# 3491             Multimodal Sentiment Analysis
# 3492            Task-Oriented Dialogue Systems
# 3493                       Dialogue Management
# 3494                                  ARQMath2
#
#                                             description children parents  \
# 0         Depth-only Anomaly Detection and Segmentation
# 1
# 2
# 3
# 4
# ...                                                 ...      ...     ...
# 3490
# 3491  Multimodal sentiment analysis is the task of p...
# 3492     Achieving a pre-defined task through a dialog.
# 3493  <span style="color:grey; opacity: 0.6">( Image...
# 3494  Answer Retrieval for Questions about Math v2 (...
#
#       num_evals
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 3490          0
# 3491          0
# 3492          0
# 3493          0
# 3494          0
#
# [3495 rows x 7 columns]

# %%
# Step 2: Load children
for file in os.listdir(DATA_DIR):
    if file.startswith('task_') and file.endswith('_children.json'):
        task_id = file[len('task_'):-len('_children.json')]
        with open(os.path.join(DATA_DIR, file), 'r') as f:
            children = json.load(f)
            children_ids = [child['id'] for child in children]
            children_str = ','.join(children_ids)
            tasks_df.loc[tasks_df['id'] == task_id, 'children'] = children_str

print("Updated DataFrame with Children:")
tasks_df
# Out:
# Updated DataFrame with Children:
#                              area                                        id  \
# 0                     methodology  depth-anomaly-detection-and-segmentation
# 1                     methodology                     stroke-classification
# 2                     methodology                neural-network-compression
# 3                     methodology           transfer-reinforcement-learning
# 4                     methodology                        variable-selection
# ...                           ...                                       ...
# 3490  natural-language-processing                    nonsense-words-grammar
# 3491  natural-language-processing             multimodal-sentiment-analysis
# 3492  natural-language-processing            task-oriented-dialogue-systems
# 3493  natural-language-processing                       dialogue-management
# 3494  natural-language-processing                                  arqmath2
#
#                                           name  \
# 0     Depth Anomaly Detection and Segmentation
# 1                        Stroke Classification
# 2                   Neural Network Compression
# 3              Transfer Reinforcement Learning
# 4                           Variable Selection
# ...                                        ...
# 3490                    Nonsense Words Grammar
# 3491             Multimodal Sentiment Analysis
# 3492            Task-Oriented Dialogue Systems
# 3493                       Dialogue Management
# 3494                                  ARQMath2
#
#                                             description            children  \
# 0         Depth-only Anomaly Detection and Segmentation
# 1
# 2
# 3
# 4                                                        variable-selection
# ...                                                 ...                 ...
# 3490
# 3491  Multimodal sentiment analysis is the task of p...
# 3492     Achieving a pre-defined task through a dialog.               sstod
# 3493  <span style="color:grey; opacity: 0.6">( Image...
# 3494  Answer Retrieval for Questions about Math v2 (...            arqmath2
#
#      parents  num_evals
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...      ...        ...
# 3490                  0
# 3491                  0
# 3492                  0
# 3493                  0
# 3494                  0
#
# [3495 rows x 7 columns]

# %%
# Step 3: Load parents
for file in os.listdir(DATA_DIR):
    if file.startswith('task_') and file.endswith('_parents.json'):
        task_id = file[len('task_'):-len('_parents.json')]
        with open(os.path.join(DATA_DIR, file), 'r') as f:
            parents = json.load(f)
            parents_ids = [parent['id'] for parent in parents]
            parents_str = ','.join(parents_ids)
            tasks_df.loc[tasks_df['id'] == task_id, 'parents'] = parents_str

print("Updated DataFrame with Parents:")
tasks_df
# Out:
# Updated DataFrame with Parents:
#                              area                                        id  \
# 0                     methodology  depth-anomaly-detection-and-segmentation
# 1                     methodology                     stroke-classification
# 2                     methodology                neural-network-compression
# 3                     methodology           transfer-reinforcement-learning
# 4                     methodology                        variable-selection
# ...                           ...                                       ...
# 3490  natural-language-processing                    nonsense-words-grammar
# 3491  natural-language-processing             multimodal-sentiment-analysis
# 3492  natural-language-processing            task-oriented-dialogue-systems
# 3493  natural-language-processing                       dialogue-management
# 3494  natural-language-processing                                  arqmath2
#
#                                           name  \
# 0     Depth Anomaly Detection and Segmentation
# 1                        Stroke Classification
# 2                   Neural Network Compression
# 3              Transfer Reinforcement Learning
# 4                           Variable Selection
# ...                                        ...
# 3490                    Nonsense Words Grammar
# 3491             Multimodal Sentiment Analysis
# 3492            Task-Oriented Dialogue Systems
# 3493                       Dialogue Management
# 3494                                  ARQMath2
#
#                                             description            children  \
# 0         Depth-only Anomaly Detection and Segmentation
# 1
# 2
# 3
# 4                                                        variable-selection
# ...                                                 ...                 ...
# 3490
# 3491  Multimodal sentiment analysis is the task of p...
# 3492     Achieving a pre-defined task through a dialog.               sstod
# 3493  <span style="color:grey; opacity: 0.6">( Image...
# 3494  Answer Retrieval for Questions about Math v2 (...            arqmath2
#
#                                   parents  num_evals
# 0                       anomaly-detection          0
# 1                  computed-tomography-ct          0
# 2     model-compression,2d-classification          0
# 3                       transfer-learning          0
# 4                      variable-selection          0
# ...                                   ...        ...
# 3490                reading-comprehension          0
# 3491                   sentiment-analysis          0
# 3492                             dialogue          0
# 3493                             dialogue          0
# 3494                             arqmath2          0
#
# [3495 rows x 7 columns]

# %%
# Step 4: Load evaluations
for file in os.listdir(DATA_DIR):
    if file.startswith('task_') and file.endswith('_evaluations.json'):
        task_id = file[len('task_'):-len('_evaluations.json')]
        with open(os.path.join(DATA_DIR, file), 'r') as f:
            evaluations = json.load(f)
            num_evals = len(evaluations)
            tasks_df.loc[tasks_df['id'] == task_id, 'num_evals'] = num_evals

print("Updated DataFrame with Evaluations:")
tasks_df
# Out:
# Updated DataFrame with Evaluations:
#                              area                                        id  \
# 0                     methodology  depth-anomaly-detection-and-segmentation
# 1                     methodology                     stroke-classification
# 2                     methodology                neural-network-compression
# 3                     methodology           transfer-reinforcement-learning
# 4                     methodology                        variable-selection
# ...                           ...                                       ...
# 3490  natural-language-processing                    nonsense-words-grammar
# 3491  natural-language-processing             multimodal-sentiment-analysis
# 3492  natural-language-processing            task-oriented-dialogue-systems
# 3493  natural-language-processing                       dialogue-management
# 3494  natural-language-processing                                  arqmath2
#
#                                           name  \
# 0     Depth Anomaly Detection and Segmentation
# 1                        Stroke Classification
# 2                   Neural Network Compression
# 3              Transfer Reinforcement Learning
# 4                           Variable Selection
# ...                                        ...
# 3490                    Nonsense Words Grammar
# 3491             Multimodal Sentiment Analysis
# 3492            Task-Oriented Dialogue Systems
# 3493                       Dialogue Management
# 3494                                  ARQMath2
#
#                                             description            children  \
# 0         Depth-only Anomaly Detection and Segmentation
# 1
# 2
# 3
# 4                                                        variable-selection
# ...                                                 ...                 ...
# 3490
# 3491  Multimodal sentiment analysis is the task of p...
# 3492     Achieving a pre-defined task through a dialog.               sstod
# 3493  <span style="color:grey; opacity: 0.6">( Image...
# 3494  Answer Retrieval for Questions about Math v2 (...            arqmath2
#
#                                   parents  num_evals
# 0                       anomaly-detection          1
# 1                  computed-tomography-ct          1
# 2     model-compression,2d-classification          1
# 3                       transfer-learning          0
# 4                      variable-selection          0
# ...                                   ...        ...
# 3490                reading-comprehension          1
# 3491                   sentiment-analysis          5
# 3492                             dialogue          4
# 3493                             dialogue          0
# 3494                             arqmath2          0
#
# [3495 rows x 7 columns]

# %%
# Save the final DataFrame to a CSV file for inspection (optional)
tasks_df.to_csv('../data/interim/tasks_by_area.csv', index=False)

# %% [markdown]
# Dataframe 2: Evaluations by Task

# %%
import os
import json
import pandas as pd

# Load the previously created DataFrame 1
tasks_df = pd.read_csv('../data/interim/tasks_by_area.csv')
print("Tasks DataFrame:")
print(tasks_df.head())
# Out:
# Tasks DataFrame:
#           area                                        id  \
# 0  methodology  depth-anomaly-detection-and-segmentation
# 1  methodology                     stroke-classification
# 2  methodology                neural-network-compression
# 3  methodology           transfer-reinforcement-learning
# 4  methodology                        variable-selection
#
#                                        name  \
# 0  Depth Anomaly Detection and Segmentation
# 1                     Stroke Classification
# 2                Neural Network Compression
# 3           Transfer Reinforcement Learning
# 4                        Variable Selection
#
#                                      description            children  \
# 0  Depth-only Anomaly Detection and Segmentation                 NaN
# 1                                            NaN                 NaN
# 2                                            NaN                 NaN
# 3                                            NaN                 NaN
# 4                                            NaN  variable-selection
#
#                                parents  num_evals
# 0                    anomaly-detection          1
# 1               computed-tomography-ct          1
# 2  model-compression,2d-classification          1
# 3                    transfer-learning          0
# 4                   variable-selection          0

# %%
DATA_DIR = '../data/raw'

def load_json(file_path):
    with open(file_path, 'r') as f:
        return json.load(f)

def extract_all_dataset_names(tasks_df):
    dataset_names = {}
    
    for task_id in tasks_df['id']:
        evaluations_file = os.path.join(DATA_DIR, f'task_{task_id}_evaluations.json')
        if os.path.exists(evaluations_file):
            evaluations = load_json(evaluations_file)
            for eval in evaluations:
                eval_id = eval['id']
                dataset_name = eval['dataset']
                dataset_names[eval_id] = dataset_name
    
    return dataset_names

# Extract dataset names for all tasks
all_dataset_names = extract_all_dataset_names(tasks_df)
print(f"All Dataset Names: {all_dataset_names}")
# Out:
# All Dataset Names: {'depth-anomaly-detection-and-segmentation-on': 'mvtec-3d-ad', 'stroke-classification-on-ct-lesion-stroke': 'ct-lesion-stroke-dataset', 'neural-network-compression-on-cifar-10': 'cifar-10', 'explanation-fidelity-evaluation-on-sst-5': 'sst-5', 'explanation-fidelity-evaluation-on-mutag': 'mutag', 'explanation-fidelity-evaluation-on-bbbp': 'bbbp', 'explanation-fidelity-evaluation-on-sst2': 'sst2', 'explanation-fidelity-evaluation-on-ba-shapes': 'ba-shapes', 'explanation-fidelity-evaluation-on-ba-2motifs': 'ba-2motifs', 'bayesian-inference-on-cifar100': 'cifar100', 'multi-task-learning-on-qm9': 'qm9', 'multi-task-learning-on-omniglot': 'omniglot', 'multi-task-learning-on-celeba': 'celeba', 'multi-task-learning-on-wireframe-dataset': 'wireframe-dataset', 'multi-task-learning-on-utkface': 'utkface', 'multi-task-learning-on-chestx-ray14': 'chestx-ray14', 'multi-task-learning-on-cityscapes': 'cityscapes-test', 'multi-task-learning-on-nyuv2': 'nyuv2', 'chatbot-on-alpacaeval': 'alpacaeval', 'multi-label-text-classification-on-rcv1-v2-1': 'rcv1-v2', 'multi-label-text-classification-on-lf-1': 'lf-amazontitles-131k', 'multi-label-text-classification-on-mvictor': 'mvictor-theme', 'multi-label-text-classification-on-bvictor': 'bvictor', 'multi-label-text-classification-on-reuters-1': 'reuters-21578', 'multi-label-text-classification-on-slashdot-1': 'slashdot', 'multi-label-text-classification-on-freecode': 'freecode', 'multi-label-text-classification-on-mimic-iii-1': 'mimic-iii-50', 'multi-label-text-classification-on-aapd': 'aapd', 'multi-label-text-classification-on-uspto-3m': 'uspto-3m', 'multi-label-text-classification-on-lf': 'lf-amzontitles-131k', 'multi-label-text-classification-on-wiki-30k': 'wiki-30k', 'multi-label-text-classification-on-eur-lex': 'eur-lex', 'multi-label-text-classification-on-svictor': 'svictor-theme', 'multi-label-text-classification-on-rcv1': 'rcv1', 'multi-label-text-classification-on-kan-shan': 'kan-shan-cup', 'multi-label-text-classification-on-mimic-iii': 'mimic-iii', 'multi-label-text-classification-on-cc3m': 'cc3m-tagmask', 'multi-label-text-classification-on-amazon-12k': 'amazon-12k', 'multi-label-text-classification-on-dataset-of': 'dataset-of-propaganda-techniques-of-the-state', 'continual-learning-on-cifar100-20-tasks-1': 'cifar100-20-tasks-1-epoch', 'continual-learning-on-rotated-mnist': 'rotated-mnist', 'continual-learning-on-split-mnist-5-tasks': 'split-mnist-5-tasks', 'continual-learning-on-coarse-cifar100': 'coarse-cifar100', 'continual-learning-on-cifar100-20-tasks': 'cifar100-20-tasks', 'continual-learning-on-imagenet-fine-grained-6': 'imagenet-fine-grained-6-tasks', 'continual-learning-on-f-celeba-10-tasks': 'f-celeba-10-tasks', 'continual-learning-on-sketch-fine-grained-6': 'sketch-fine-grained-6-tasks', 'continual-learning-on-mlt17': 'mlt17', 'continual-learning-on-stanford-cars-fine': 'stanford-cars-fine-grained-6-tasks', 'continual-learning-on-asc-19-tasks': 'asc-19-tasks', 'continual-learning-on-split-cifar-10-5-tasks': 'split-cifar-10-5-tasks', 'continual-learning-on-miniimagenet-resnet-18': 'miniimagenet-resnet-18-300-epochs', 'continual-learning-on-tiny-imagenet-10tasks': 'tiny-imagenet-10tasks', 'continual-learning-on-tinyimagenet-resnet-18': 'tinyimagenet-resnet-18-300-epochs', 'continual-learning-on-cub-200-2011-20-tasks-1': 'cub-200-2011-20-tasks-1-epoch', 'continual-learning-on-cubs-fine-grained-6': 'cubs-fine-grained-6-tasks', 'continual-learning-on-flowers-fine-grained-6': 'flowers-fine-grained-6-tasks', 'continual-learning-on-wikiart-fine-grained-6': 'wikiart-fine-grained-6-tasks', 'continual-learning-on-permuted-mnist': 'permuted-mnist', 'continual-learning-on-5-dataset-1-epoch': '5-dataset-1-epoch', 'continual-learning-on-mini-imagenet-20-tasks': 'mini-imagenet-20-tasks-1-epoch', 'continual-learning-on-dsc-10-tasks': 'dsc-10-tasks', 'continual-learning-on-cifar100-10-tasks': 'cifar100-10-tasks', 'continual-learning-on-cifar-100-resnet-18-300': 'cifar-100-resn ...

# %%
def find_evaluations(task_id):
    evaluations = []
    eval_prefix = f"evaluation_{task_id}-on"
    eval_suffix = "_results.json"
    
    for file in os.listdir(DATA_DIR):
        if file.startswith(eval_prefix) and file.endswith(eval_suffix):
            eval_file = os.path.join(DATA_DIR, file)
            evaluations.append(eval_file)
    
    return evaluations

# Test for one task
sample_task_id = tasks_df['id'].iloc[0]
evaluation_files = find_evaluations(sample_task_id)
print(f"Evaluation files for task {sample_task_id}: {evaluation_files}")
# Out:
# Evaluation files for task depth-anomaly-detection-and-segmentation: ['../data/raw/evaluation_depth-anomaly-detection-and-segmentation-on_results.json']

# %%
def extract_evaluation_results(evaluation_file):
    evaluation_results = load_json(evaluation_file)
    results = []

    for eval in evaluation_results:
        metrics = eval['metrics']
        model = eval['methodology']
        paper = eval['paper']
        date = eval['evaluated_on']
        
        for metric_name, metric_value in metrics.items():
            results.append({
                'metric': metric_name,
                'value': metric_value,
                'model': model,
                'paper': paper,
                'date': date
            })
    
    return results

# Test for one evaluation file
sample_evaluation_file = evaluation_files[0]
evaluation_results = extract_evaluation_results(sample_evaluation_file)
print(f"Evaluation results for file {sample_evaluation_file}: {evaluation_results}")
# Out:
# Evaluation results for file ../data/raw/evaluation_depth-anomaly-detection-and-segmentation-on_results.json: [{'metric': 'Segmentation AUPRO', 'value': '0.9293', 'model': 'CPMF (2D+3D)', 'paper': 'complementary-pseudo-multimodal-feature-for', 'date': '2023-03-23'}, {'metric': 'Detection AUROC', 'value': '0.9515', 'model': 'CPMF (2D+3D)', 'paper': 'complementary-pseudo-multimodal-feature-for', 'date': '2023-03-23'}, {'metric': 'Segmentation AUROC', 'value': '0.9781', 'model': 'CPMF (2D+3D)', 'paper': 'complementary-pseudo-multimodal-feature-for', 'date': '2023-03-23'}, {'metric': 'Segmentation AUPRO', 'value': '0.9230', 'model': 'CPMF (3D)', 'paper': 'complementary-pseudo-multimodal-feature-for', 'date': '2023-03-23'}, {'metric': 'Detection AUROC', 'value': '0.8304', 'model': 'CPMF (3D)', 'paper': 'complementary-pseudo-multimodal-feature-for', 'date': '2023-03-23'}, {'metric': 'Segmentation AUROC', 'value': '0.9780', 'model': 'CPMF (3D)', 'paper': 'complementary-pseudo-multimodal-feature-for', 'date': '2023-03-23'}, {'metric': 'Segmentation AUPRO', 'value': '0.9145', 'model': 'CPMF (2D)', 'paper': 'complementary-pseudo-multimodal-feature-for', 'date': '2023-03-23'}, {'metric': 'Detection AUROC', 'value': '0.8918', 'model': 'CPMF (2D)', 'paper': 'complementary-pseudo-multimodal-feature-for', 'date': '2023-03-23'}, {'metric': 'Segmentation AUROC', 'value': '0.9730', 'model': 'CPMF (2D)', 'paper': 'complementary-pseudo-multimodal-feature-for', 'date': '2023-03-23'}, {'metric': 'Segmentation AUPRO', 'value': '0.910', 'model': 'Back to the Feature:\nClassical 3D Features are (Almost) All You Need for 3D Anomaly Detection (SIFT)', 'paper': 'an-empirical-investigation-of-3d-anomaly', 'date': '2022-03-10'}, {'metric': 'Detection AUROC', 'value': '0.727', 'model': 'Back to the Feature:\nClassical 3D Features are (Almost) All You Need for 3D Anomaly Detection (SIFT)', 'paper': 'an-empirical-investigation-of-3d-anomaly', 'date': '2022-03-10'}, {'metric': 'Segmentation AUROC', 'value': '0.974', 'model': 'Back to the Feature:\nClassical 3D Features are (Almost) All You Need for 3D Anomaly Detection (SIFT)', 'paper': 'an-empirical-investigation-of-3d-anomaly', 'date': '2022-03-10'}, {'metric': 'Segmentation AUPRO', 'value': '0.907', 'model': '3DSR (3D)', 'paper': 'cheating-depth-enhancing-3d-surface-anomaly', 'date': '2023-11-02'}, {'metric': 'Detection AUROC', 'value': '0.922', 'model': '3DSR (3D)', 'paper': 'cheating-depth-enhancing-3d-surface-anomaly', 'date': '2023-11-02'}, {'metric': 'Segmentation AUPRO', 'value': '0.771', 'model': 'Back to the Feature:\nClassical 3D Features are (Almost) All You Need for 3D Anomaly Detection  (HoG)', 'paper': 'an-empirical-investigation-of-3d-anomaly', 'date': '2022-03-10'}, {'metric': 'Detection AUROC', 'value': '0.559', 'model': 'Back to the Feature:\nClassical 3D Features are (Almost) All You Need for 3D Anomaly Detection  (HoG)', 'paper': 'an-empirical-investigation-of-3d-anomaly', 'date': '2022-03-10'}, {'metric': 'Segmentation AUROC', 'value': '0.930', 'model': 'Back to the Feature:\nClassical 3D Features are (Almost) All You Need for 3D Anomaly Detection  (HoG)', 'paper': 'an-empirical-investigation-of-3d-anomaly', 'date': '2022-03-10'}, {'metric': 'Segmentation AUPRO', 'value': '0.755', 'model': 'Back to the Feature:\nClassical 3D Features are (Almost) All You Need for 3D Anomaly Detection  (Depth iNet)', 'paper': 'an-empirical-investigation-of-3d-anomaly', 'date': '2022-03-10'}, {'metric': 'Detection AUROC', 'value': '0.675', 'model': 'Back to the Feature:\nClassical 3D Features are (Almost) All You Need for 3D Anomaly Detection  (Depth iNet)', 'paper': 'an-empirical-investigation-of-3d-anomaly', 'date': '2022-03-10'}, {'metric': 'Segmentation AUROC', 'value': '0.930', 'model': 'Back to the Feature:\nClassical 3D Features are (Almost) All You Need for 3D Anomaly Detection  (Depth iNet)', 'paper': 'an-empirical-investigation-of-3d-anomaly', 'date': '2022-03-10'}, {'metric': 'Segmentation AUPRO' ...

# %%
# Initialize a list to store the final data
evaluation_data = []

for task_id in tasks_df['id']:
    evaluation_files = find_evaluations(task_id)
    
    for eval_file in evaluation_files:
        # Extract eval_id from the filename
        eval_id = eval_file[len(DATA_DIR) + 1 + len('evaluation_'):-len('_results.json')]
        
        # Debug: Print the extracted eval_id
        print(f"Extracted eval_id: {eval_id}")
        
        # Get the dataset name from the all_dataset_names dictionary
        dataset_name = all_dataset_names.get(eval_id, 'Unknown')
        
        # Debug: Print the matched dataset name
        print(f"Matched dataset name: {dataset_name}")
        
        # Extract the evaluation results
        evaluation_results = extract_evaluation_results(eval_file)
        
        for result in evaluation_results:
            evaluation_data.append({
                'Task': task_id,
                'Dataset': dataset_name,
                'Metric': result['metric'],
                'Value': result['value'],
                'Model': result['model'],
                'Paper': result['paper'],
                'Date': result['date']
            })

# Create the DataFrame from the collected data
evaluations_df = pd.DataFrame(evaluation_data)
print("Evaluations DataFrame:")
print(evaluations_df.head())
# Out:
# Extracted eval_id: depth-anomaly-detection-and-segmentation-on
# Matched dataset name: mvtec-3d-ad
# Extracted eval_id: stroke-classification-on-ct-lesion-stroke
# Matched dataset name: ct-lesion-stroke-dataset
# Extracted eval_id: neural-network-compression-on-cifar-10
# Matched dataset name: cifar-10
# Extracted eval_id: explanation-fidelity-evaluation-on-ba-2motifs
# Matched dataset name: ba-2motifs
# Extracted eval_id: explanation-fidelity-evaluation-on-sst2
# Matched dataset name: sst2
# Extracted eval_id: explanation-fidelity-evaluation-on-ba-shapes
# Matched dataset name: ba-shapes
# Extracted eval_id: explanation-fidelity-evaluation-on-bbbp
# Matched dataset name: bbbp
# Extracted eval_id: explanation-fidelity-evaluation-on-mutag
# Matched dataset name: mutag
# Extracted eval_id: explanation-fidelity-evaluation-on-sst-5
# Matched dataset name: sst-5
# Extracted eval_id: bayesian-inference-on-cifar100
# Matched dataset name: cifar100
# Extracted eval_id: multi-task-learning-on-wireframe-dataset
# Matched dataset name: wireframe-dataset
# Extracted eval_id: multi-task-learning-on-celeba
# Matched dataset name: celeba
# Extracted eval_id: multi-task-learning-on-chestx-ray14
# Matched dataset name: chestx-ray14
# Extracted eval_id: multi-task-learning-on-nyuv2
# Matched dataset name: nyuv2
# Extracted eval_id: multi-task-learning-on-omniglot
# Matched dataset name: omniglot
# Extracted eval_id: multi-task-learning-on-cityscapes
# Matched dataset name: cityscapes-test
# Extracted eval_id: multi-task-learning-on-utkface
# Matched dataset name: utkface
# Extracted eval_id: multi-task-learning-on-qm9
# Matched dataset name: qm9
# Extracted eval_id: chatbot-on-alpacaeval
# Matched dataset name: alpacaeval
# Extracted eval_id: multi-label-text-classification-on-reuters-1
# Matched dataset name: reuters-21578
# Extracted eval_id: multi-label-text-classification-on-cc3m
# Matched dataset name: cc3m-tagmask
# Extracted eval_id: multi-label-text-classification-on-uspto-3m
# Matched dataset name: uspto-3m
# Extracted eval_id: multi-label-text-classification-on-rcv1
# Matched dataset name: rcv1
# Extracted eval_id: multi-label-text-classification-on-eur-lex
# Matched dataset name: eur-lex
# Extracted eval_id: multi-label-text-classification-on-bvictor
# Matched dataset name: bvictor
# Extracted eval_id: multi-label-text-classification-on-slashdot-1
# Matched dataset name: slashdot
# Extracted eval_id: multi-label-text-classification-on-svictor
# Matched dataset name: svictor-theme
# Extracted eval_id: multi-label-text-classification-on-aapd
# Matched dataset name: aapd
# Extracted eval_id: multi-label-text-classification-on-amazon-12k
# Matched dataset name: amazon-12k
# Extracted eval_id: multi-label-text-classification-on-kan-shan
# Matched dataset name: kan-shan-cup
# Extracted eval_id: multi-label-text-classification-on-rcv1-v2-1
# Matched dataset name: rcv1-v2
# Extracted eval_id: multi-label-text-classification-on-mimic-iii
# Matched dataset name: mimic-iii
# Extracted eval_id: multi-label-text-classification-on-mimic-iii-1
# Matched dataset name: mimic-iii-50
# Extracted eval_id: multi-label-text-classification-on-dataset-of
# Matched dataset name: dataset-of-propaganda-techniques-of-the-state
# Extracted eval_id: multi-label-text-classification-on-lf-1
# Matched dataset name: lf-amazontitles-131k
# Extracted eval_id: multi-label-text-classification-on-wiki-30k
# Matched dataset name: wiki-30k
# Extracted eval_id: multi-label-text-classification-on-freecode
# Matched dataset name: freecode
# Extracted eval_id: multi-label-text-classification-on-mvictor
# Matched dataset name: mvictor-theme
# Extracted eval_id: multi-label-text-classification-on-lf
# Matched dataset name: lf-amzontitles-131k
# Extracted eval_id: continual-learning-on-coarse-cifar100
# Matched dataset name: coarse-cifar100
# Extracted eval_id: continual-learning-on-tiny-imagenet-10tasks
# Matched dataset name: tiny-imagenet-10tasks
# Extracted eval_id: continual-learning-on-mini-imagenet-20-tasks
# Matched dataset name: mini-imagenet-20-tasks-1-epoch
# Extracted eval_id: continual-learning-on-miniimagenet-resnet-18
# Matched dataset name: miniimagenet-resnet-18-300-epochs
# Extracted eval_id: continual-learning-on-cifar100-20-tasks-1
# Matched dataset name: cifar100-20-tasks-1-epoch
# Extracted eval_id: continual-learning-on-imagenet-fine-grained-6
# Matched dataset name: imagenet-fine-grained-6-tasks
# Extracted eval_id: continual-learning-on-stanford-cars-fine
# Matched dataset name: stanford-cars-fine-grained-6-tasks
# Extracted eval_id: continual-learning-on-rotated-mnist
# Matched dataset name: rotated-mnist
# Extracted eval_id: continual-learning-on-cifar-100-alexnet-300
# Matched dataset name: cifar-100-alexnet-300-epoch
# Extracted eval_id: continual-learning-on-cubs-fine-grained-6
# Matched dataset name: cubs-fine-grained-6-tasks
# Extracted eval_id: continual-learning-on-cifar100-10-tasks
# Matched dataset name: cifar100-10-tasks
# Extracted eval_id: continual-learning-on-cifar-100-resnet-18-300
# Matched dataset name: cifar-100-resnet-18-300-epochs
# Extracted eval_id: continual-learning-on-wikiart-fine-grained-6
# Matched dataset name: wikiart-fine-grained-6-tasks
# Extracted eval_id: continual-learning-on-split-cifar-10-5-tasks
# Matched dataset name: split-cifar-10-5-tasks
# Extracted eval_id: continual-learning-on-mlt17
# Matched dataset name: mlt17
# Extracted eval_id: continual-learning-on-cifar100-20-tasks
# Matched dataset name: cifar100-20-tasks
# Extracted eval_id: continual-learning-on-imagenet-50-5-tasks
# Matched dataset name: imagenet-50-5-tasks
# Extracted eval_id: continual-learning-on-split-mnist-5-tasks
# Matched dataset name: split-mnist-5-tasks
# Extracted eval_id: continual-learning-on-flowers-fine-grained-6
# Matched dataset name: flowers-fine-grained-6-tasks
# Extracted eval_id: continual-learning-on-5-dataset-1-epoch
# Matched dataset name: 5-dataset-1-epoch
# Extracted eval_id: continual-learning-on-sketch-fine-grained-6
# Matched dataset name: sketch-fine-grained-6-tasks
# Extracted eval_id: continual-learning-on-dsc-10-tasks
# Matched dataset name: dsc-10-tasks
# Extracted eval_id: continual-learning-on-cub-200-2011-20-tasks-1
# Matched dataset name: cub-200-2011-20-tasks-1-epoch
# Extracted eval_id: continual-learning-on-tinyimagenet-resnet-18
# Matched dataset name: tinyimagenet-resnet-18-300-epochs
# Extracted eval_id: continual-learning-on-asc-19-tasks
# Matched dataset name: asc-19-tasks
# Extracted eval_id: continual-learning-on-visual-domain-decathlon
# Matched dataset name: visual-domain-decathlon-10-tasks
# Extracted eval_id: continual-learning-on-f-celeba-10-tasks
# Matched dataset name: f-celeba-10-tasks
# Extracted eval_id: continual-learning-on-20newsgroup-10-tasks
# Matched dataset name: 20newsgroup-10-tasks
# Extracted eval_id: continual-learning-on-permuted-mnist
# Matched dataset name: permuted-mnist
# Extracted eval_id: unsupervised-anomaly-detection-on-caltech-101-1
# Matched dataset name: caltech-101
# Extracted eval_id: unsupervised-anomaly-detection-on-stl-10
# Matched dataset name: stl-10
# Extracted eval_id: unsupervised-anomaly-detection-on-pronto
# Matched dataset name: pronto
# Extracted eval_id: unsupervised-anomaly-detection-on-anoshift
# Matched dataset name: anoshift
# Extracted eval_id: unsupervised-anomaly-detection-on-kolektorsdd
# Matched dataset name: kolektorsdd
# Extracted eval_id: unsupervised-anomaly-detection-on-20news-1
# Matched dataset name: 20news
# Extracted eval_id: unsupervised-anomaly-detection-on-vehicle
# Matched dataset name: vehicle-claims
# Extracted eval_id: unsupervised-anomaly-detection-on-smap
# Matched dataset name: smap
# Extracted eval_id: unsupervised-anomaly-detection-on-ecg5000
# Matched dataset name: ecg5000
# Extracted eval_id: unsupervised-anomaly-detection-on-timo
# Matched dataset name: timo
# Extracted eval_id: unsupervised-anomaly-detection-on-synthetic
# Matched dataset name: synthetic
# Extracted eval_id: unsupervised-anomaly-detection-on-mnist-1
# Matched dataset name: mnist
# Extracted eval_id: unsupervised-anomaly-detection-on-reuters-1
# Matched dataset name: reuters-21578
# Extracted eval_id: unsupervised-anomaly-detection-on-dagm2007
# Matched dataset name: dagm2007
# Extracted eval_id: unsupervised-anomaly-detection-on
# Matched dataset name: kolektorsdd2
# Extracted eval_id: unsupervised-anomaly-detection-on-fashion-1
# Matched dataset name: fashion-mnist
# Extracted eval_id: active-learning-on-cifar10-10000
# Matched dataset name: cifar10-10000
# Extracted eval_id: few-shot-relation-classification-on-fredo
# Matched dataset name: fredo
# Extracted eval_id: few-shot-relation-classification-on-docred
# Matched dataset name: docred
# Extracted eval_id: few-shot-relation-classification-on-fredo-1
# Matched dataset name: fredo-cross-domain
# Extracted eval_id: few-shot-relation-classification-on-scierc
# Matched dataset name: scierc
# Extracted eval_id: partial-domain-adaptation-on-office-home
# Matched dataset name: office-home
# Extracted eval_id: partial-domain-adaptation-on-office-31
# Matched dataset name: office-31
# Extracted eval_id: partial-domain-adaptation-on-domainnet
# Matched dataset name: domainnet
# Extracted eval_id: partial-domain-adaptation-on-imagenet-caltech
# Matched dataset name: imagenet-caltech
# Extracted eval_id: partial-domain-adaptation-on-visda2017
# Matched dataset name: visda2017
# Extracted eval_id: personalized-federated-learning-on-mnist-1
# Matched dataset name: mnist
# Extracted eval_id: personalized-federated-learning-on-cifar-10
# Matched dataset name: cifar-10
# Extracted eval_id: personalized-federated-learning-on-omniglot
# Matched dataset name: omniglot-1
# Extracted eval_id: personalized-federated-learning-on-tiny
# Matched dataset name: tiny-imagenet
# Extracted eval_id: personalized-federated-learning-on-cifar-100
# Matched dataset name: cifar-100
# Extracted eval_id: personalized-federated-learning-on-femnist
# Matched dataset name: femnist
# Extracted eval_id: personalized-federated-learning-on
# Matched dataset name: shakespeare
# Extracted eval_id: architecture-search-on-cifar-10-image
# Matched dataset name: cifar-10-image-classification
# Extracted eval_id: rgb-3d-anomaly-detection-and-segmentation-on
# Matched dataset name: mvtec-3d-ad
# Extracted eval_id: multi-label-learning-on-coco-2014
# Matched dataset name: coco-2014
# Extracted eval_id: continuously-indexed-domain-adaptation-on-2
# Matched dataset name: sine
# Extracted eval_id: continuously-indexed-domain-adaptation-on-3
# Matched dataset name: indexed-rotating-mnist
# Extracted eval_id: continuously-indexed-domain-adaptation-on-1
# Matched dataset name: circle
# Extracted eval_id: unsupervised-domain-adaptation-on-cuhk03-to
# Matched dataset name: cuhk03-to-msmt
# Extracted eval_id: unsupervised-domain-adaptation-on-cuhk03-to-1
# Matched dataset name: cuhk03-to-market
# Extracted eval_id: unsupervised-domain-adaptation-on-cfc-daod
# Matched dataset name: cfc-daod
# Extracted eval_id: unsupervised-domain-adaptation-on-sim10k-to-2
# Matched dataset name: sim10k-to-bdd100k
# Extracted eval_id: unsupervised-domain-adaptation-on-hmdb-ucf
# Matched dataset name: hmdb-ucf
# Extracted eval_id: unsupervised-domain-adaptation-on-ood-cv
# Matched dataset name: ood-cv
# Extracted eval_id: unsupervised-domain-adaptation-on-sim10k-to-3
# Matched dataset name: sim10k-to-cityscapes
# Extracted eval_id: unsupervised-domain-adaptation-on-imagenet-c
# Matched dataset name: imagenet-c
# Extracted eval_id: unsupervised-domain-adaptation-on-fhist
# Matched dataset name: fhist
# Extracted eval_id: unsupervised-domain-adaptation-on-ucf-hmdb
# Matched dataset name: ucf-hmdb
# Extracted eval_id: unsupervised-domain-adaptation-on-epic
# Matched dataset name: epic-kitchens-100
# Extracted eval_id: unsupervised-domain-adaptation-on-pascal-voc
# Matched dataset name: pascal-voc-to-clipart1k
# Extracted eval_id: unsupervised-domain-adaptation-on-mscoco-to
# Matched dataset name: mscoco-to-flir-adas
# Extracted eval_id: unsupervised-domain-adaptation-on-pacs
# Matched dataset name: pacs
# Extracted eval_id: unsupervised-domain-adaptation-on-gta5
# Matched dataset name: gta5-synscapes-urbansyn-to-cityscapes
# Extracted eval_id: unsupervised-domain-adaptation-on-cityscapes-2
# Matched dataset name: cityscapes-to-oxfordcar
# Extracted eval_id: unsupervised-domain-adaptation-on-jester-1
# Matched dataset name: jester-gesture-recognition
# Extracted eval_id: unsupervised-domain-adaptation-on-portraits
# Matched dataset name: portraits-over-time
# Extracted eval_id: unsupervised-domain-adaptation-on-visda2017
# Matched dataset name: visda2017
# Extracted eval_id: unsupervised-domain-adaptation-on-market-to-1
# Matched dataset name: market-to-msmt
# Extracted eval_id: unsupervised-domain-adaptation-on-market-to-6
# Matched dataset name: market-to-cuhk03
# Extracted eval_id: unsupervised-domain-adaptation-on-imagenet-r
# Matched dataset name: imagenet-r
# Extracted eval_id: unsupervised-domain-adaptation-on-gta5-to-3
# Matched dataset name: gta5-to-cityscapes-1
# Extracted eval_id: unsupervised-domain-adaptation-on-office-home
# Matched dataset name: office-home
# Extracted eval_id: unsupervised-domain-adaptation-on-cityscapes-1
# Matched dataset name: cityscapes-to-foggy-cityscapes
# Extracted eval_id: unsupervised-domain-adaptation-on-office-home-1
# Matched dataset name: office-home-rs-ut-imbalance
# Extracted eval_id: unsupervised-domain-adaptation-on-duke-to
# Matched dataset name: duke-to-market
# Extracted eval_id: unsupervised-domain-adaptation-on-gtav-to
# Matched dataset name: gtav-to-cityscapes-labels
# Extracted eval_id: unsupervised-domain-adaptation-on-market-to
# Matched dataset name: market-to-duke
# Extracted eval_id: unsupervised-domain-adaptation-on-presil-to-1
# Matched dataset name: presil-to-kitti
# Extracted eval_id: unsupervised-domain-adaptation-on-uda-ch
# Matched dataset name: uda-ch
# Extracted eval_id: unsupervised-domain-adaptation-on-imagenet-a
# Matched dataset name: imagenet-a
# Extracted eval_id: unsupervised-domain-adaptation-on-office-31
# Matched dataset name: office-31
# Extracted eval_id: unsupervised-domain-adaptation-on-domainnet-1
# Matched dataset name: domainnet
# Extracted eval_id: unsupervised-domain-adaptation-on-kitti-to
# Matched dataset name: kitti-to-cityscapes
# Extracted eval_id: unsupervised-domain-adaptation-on
# Matched dataset name: clonedperson
# Extracted eval_id: unsupervised-domain-adaptation-on-synthia-to
# Matched dataset name: synthia-to-cityscapes
# Extracted eval_id: unsupervised-domain-adaptation-on-bdd100k-to
# Matched dataset name: bdd100k-to-cityscapes
# Extracted eval_id: unsupervised-domain-adaptation-on-duke-to-1
# Matched dataset name: duke-to-msmt
# Extracted eval_id: zero-shot-generalization-on-calvin
# Matched dataset name: calvin-composing-actions-from-language-and
# Extracted eval_id: classification-on-full-body-parkinsons
# Matched dataset name: full-body-pd-dataset
# Extracted eval_id: classification-on-rsscn7
# Matched dataset name: rsscn7
# Extracted eval_id: classification-on-wine
# Matched dataset name: wine
# Extracted eval_id: classification-on-cwru-bearing-dataset
# Matched dataset name: cwru-bearing-dataset
# Extracted eval_id: classification-on-imagenet-c-ood-class-out-of
# Matched dataset name: imagenet-c-ood-class-out-of-distribution
# Extracted eval_id: classification-on-isic-2019
# Matched dataset name: isic-2019
# Extracted eval_id: classification-on-n-cars
# Matched dataset name: n-cars
# Extracted eval_id: classification-on-rite
# Matched dataset name: rite
# Extracted eval_id: classification-on-aur-umb-dataset
# Matched dataset name: aur-umb-dataset
# Extracted eval_id: classification-on-indl
# Matched dataset name: indl
# Extracted eval_id: classification-on-cifake-real-and-ai
# Matched dataset name: cifake-real-and-ai-generated-synthetic-images
# Extracted eval_id: classification-on-biasbios
# Matched dataset name: biasbios
# Extracted eval_id: classification-on-ximagenet-12
# Matched dataset name: ximagenet-12
# Extracted eval_id: classification-on-tcga
# Matched dataset name: tcga
# Extracted eval_id: classification-on-sentiment140
# Matched dataset name: sentiment140
# Extracted eval_id: classification-on-kepler-exoplanet-search
# Matched dataset name: kepler-exoplanet-search-results
# Extracted eval_id: classification-on-cifar-100
# Matched dataset name: cifar-100
# Extracted eval_id: classification-on-corbel
# Matched dataset name: corbel
# Extracted eval_id: classification-on-hows-long
# Matched dataset name: hows-long
# Extracted eval_id: classification-on-xor
# Matched dataset name: xor
# Extracted eval_id: classification-on-n-imagenet-mini
# Matched dataset name: n-imagenet-mini
# Extracted eval_id: classification-on-bengali-ekman-s-six-basic
# Matched dataset name: bangla-ekman-s-six-basic-emotions-dataset
# Extracted eval_id: classification-on-mixedwm38
# Matched dataset name: mixedwm38
# Extracted eval_id: classification-on-adult
# Matched dataset name: adult-data-set
# Extracted eval_id: classification-on-hrf
# Matched dataset name: hrf
# Extracted eval_id: classification-on-shd-adding
# Matched dataset name: shd-adding
# Extracted eval_id: classification-on-brain-tumor-mri-dataset
# Matched dataset name: brain-tumor-mri-dataset
# Extracted eval_id: classification-on-sgd
# Matched dataset name: sgd
# Extracted eval_id: classification-on-forgerynet
# Matched dataset name: forgerynet
# Extracted eval_id: classification-on-les-av
# Matched dataset name: les-av
# Extracted eval_id: classification-on-mured-dataset
# Matched dataset name: mured-dataset
# Extracted eval_id: classification-on-autoimmune-dataset
# Matched dataset name: autoimmune-dataset
# Extracted eval_id: classification-on-irfl-image-recognition-of
# Matched dataset name: irfl-image-recognition-of-figurative-language
# Extracted eval_id: classification-on-hows
# Matched dataset name: hows
# Extracted eval_id: classification-on-medsecid
# Matched dataset name: medsecid
# Extracted eval_id: classification-on-n-imagenet
# Matched dataset name: n-imagenet
# Extracted eval_id: classification-on-burr-classification-images
# Matched dataset name: burr-classification-images
# Extracted eval_id: classification-on-sound-based-drone-fault
# Matched dataset name: k-drone
# Extracted eval_id: classification-on-reddit-ideology-database
# Matched dataset name: reddit-ideology-database
# Extracted eval_id: classification-on-chest-x-ray-images
# Matched dataset name: chest-x-ray-images-pneumonia
# Extracted eval_id: long-tail-learning-with-class-descriptors-on-1
# Matched dataset name: sun-lt
# Extracted eval_id: long-tail-learning-with-class-descriptors-on-2
# Matched dataset name: awa-lt
# Extracted eval_id: long-tail-learning-with-class-descriptors-on-3
# Matched dataset name: imagenet-lt-d
# Extracted eval_id: long-tail-learning-with-class-descriptors-on
# Matched dataset name: cub-lt
# Extracted eval_id: disentanglement-on-kitti-masks
# Matched dataset name: kitti-masks
# Extracted eval_id: disentanglement-on-3dident
# Matched dataset name: 3dident
# Extracted eval_id: disentanglement-on-natural-sprites
# Matched dataset name: natural-sprites
# Extracted eval_id: incremental-learning-on-imagenet-100-50-3
# Matched dataset name: imagenet-100-50-classes-5-steps-of-10-classes
# Extracted eval_id: incremental-learning-on-mlt17
# Matched dataset name: mlt17
# Extracted eval_id: incremental-learning-on-imagenet-500-classes-3
# Matched dataset name: imagenet-500-classes-25-steps-of-20-classes
# Extracted eval_id: incremental-learning-on-cifar100b020step
# Matched dataset name: cifar100b020step-5classesperstep
# Extracted eval_id: incremental-learning-on-imagenet-10-steps
# Matched dataset name: imagenet-10-steps
# Extracted eval_id: incremental-learning-on-cifar-100-b0-5steps
# Matched dataset name: cifar-100-b0-5steps-of-20-classes
# Extracted eval_id: incremental-learning-on-cifar100b050s
# Matched dataset name: cifar100b050s-2classesperstep
# Extracted eval_id: incremental-learning-on-imagenet-500-classes-2
# Matched dataset name: imagenet-500-classes-10-steps-of-50-classes
# Extracted eval_id: incremental-learning-on-imagenet-100-50-2
# Matched dataset name: imagenet-100-50-classes-10-steps-of-5-classes
# Extracted eval_id: incremental-learning-on-imagenet-10k-5225
# Matched dataset name: imagenet-10k-5225-classes-5-steps-of-1045
# Extracted eval_id: incremental-learning-on-imagenet100-20-steps
# Matched dataset name: imagenet100-20-steps
# Extracted eval_id: incremental-learning-on-cifar-100-50-classes-1
# Matched dataset name: cifar-100-50-classes-25-steps-of-2-classes
# Extracted eval_id: incremental-learning-on-imagenet-100-50
# Matched dataset name: imagenet-100-50-classes-50-steps-of-1-class
# Extracted eval_id: incremental-learning-on-cifar-100-40-classes
# Matched dataset name: cifar-100-40-classes-60-steps-of-1-class
# Extracted eval_id: incremental-learning-on-imagenet100-10-steps
# Matched dataset name: imagenet100-10-steps
# Extracted eval_id: incremental-learning-on-cifar-100-50-classes-4
# Matched dataset name: cifar-100-50-classes-2-steps-of-25-classes
# Extracted eval_id: incremental-learning-on-cifar-100-50-classes-3
# Matched dataset name: cifar-100-50-classes-5-steps-of-10-classes
# Extracted eval_id: incremental-learning-on-cifar-100-50-classes-2
# Matched dataset name: cifar-100-50-classes-10-steps-of-5-classes
# Extracted eval_id: incremental-learning-on-cifar100-b0-10steps
# Matched dataset name: cifar100-b0-10steps-of-10-classes
# Extracted eval_id: incremental-learning-on-cifar-100-50-classes
# Matched dataset name: cifar-100-50-classes-50-steps-of-1-class
# Extracted eval_id: incremental-learning-on-imagenet-100-50-1
# Matched dataset name: imagenet-100-50-classes-25-steps-of-2-classes
# Extracted eval_id: incremental-learning-on-imagenet-500-classes-1
# Matched dataset name: imagenet-500-classes-5-steps-of-100-classes
# Extracted eval_id: data-free-quantization-on-cifar-100
# Matched dataset name: cifar-100
# Extracted eval_id: data-free-quantization-on-cifar10
# Matched dataset name: cifar10
# Extracted eval_id: stochastic-optimization-on-imagenet-resnet-50-2
# Matched dataset name: imagenet-resnet-50-90-epochs
# Extracted eval_id: stochastic-optimization-on-mnist
# Matched dataset name: mnist
# Extracted eval_id: stochastic-optimization-on-cola
# Matched dataset name: cola
# Extracted eval_id: stochastic-optimization-on-cifar-10-resnet-18
# Matched dataset name: cifar-10-resnet-18-200-epochs
# Extracted eval_id: stochastic-optimization-on-penn-treebank
# Matched dataset name: penn-treebank-character-level-3x1000-lstm-500
# Extracted eval_id: stochastic-optimization-on-cifar-100-wrn-28
# Matched dataset name: cifar-100-wrn-28-10-200-epochs
# Extracted eval_id: stochastic-optimization-on-cifar-10-wrn-28-10
# Matched dataset name: cifar-10-wrn-28-10-200-epochs
# Extracted eval_id: stochastic-optimization-on-imagenet-resnet-50
# Matched dataset name: imagenet-resnet-50-50-epochs
# Extracted eval_id: stochastic-optimization-on-ag-news
# Matched dataset name: ag-news
# Extracted eval_id: stochastic-optimization-on-imagenet-resnet-50-1
# Matched dataset name: imagenet-resnet-50-60-epochs
# Extracted eval_id: stochastic-optimization-on-cifar-100
# Matched dataset name: cifar-100
# Extracted eval_id: stochastic-optimization-on-cifar-10
# Matched dataset name: cifar-10
# Extracted eval_id: multi-task-language-understanding-on-bbh-alg
# Matched dataset name: bbh-alg
# Extracted eval_id: multi-task-language-understanding-on-mmlu
# Matched dataset name: mmlu
# Extracted eval_id: multi-task-language-understanding-on-mgsm
# Matched dataset name: mgsm
# Extracted eval_id: multi-task-language-understanding-on-bbh-nlp
# Matched dataset name: bbh-nlp
# Extracted eval_id: generalized-few-shot-learning-on-awa2
# Matched dataset name: awa2-1
# Extracted eval_id: generalized-few-shot-learning-on-sun
# Matched dataset name: sun
# Extracted eval_id: generalized-few-shot-learning-on-cub
# Matched dataset name: cub
# Extracted eval_id: feature-importance-on-breastcancer
# Matched dataset name: breastcancer
# Extracted eval_id: feature-importance-on-digits
# Matched dataset name: digits
# Extracted eval_id: feature-importance-on-iris
# Matched dataset name: iris-1
# Extracted eval_id: feature-importance-on-diabetes
# Matched dataset name: diabetes
# Extracted eval_id: feature-importance-on-wine
# Matched dataset name: wine
# Extracted eval_id: feature-importance-on-boston
# Matched dataset name: boston
# Extracted eval_id: automl-on-ordinaldataset
# Matched dataset name: ordinaldataset
# Extracted eval_id: automl-on-madeline
# Matched dataset name: madeline
# Extracted eval_id: domain-adaptation-on-noisy-amazon-20
# Matched dataset name: noisy-amazon-20
# Extracted eval_id: domain-adaptation-on-panoptic-synthia-to
# Matched dataset name: panoptic-synthia-to-cityscapes
# Extracted eval_id: domain-adaptation-on-noisy-mnist-to-synd
# Matched dataset name: noisy-mnist-to-synd
# Extracted eval_id: domain-adaptation-on-imageclef-da
# Matched dataset name: imageclef-da
# Extracted eval_id: domain-adaptation-on-office-home
# Matched dataset name: office-home
# Extracted eval_id: domain-adaptation-on-synthia-to
# Matched dataset name: synthia-to-foggycityscapes
# Extracted eval_id: domain-adaptation-on-ucf-to-hmdbsmall
# Matched dataset name: ucf-to-hmdbsmall
# Extracted eval_id: domain-adaptation-on-visda2017
# Matched dataset name: visda2017
# Extracted eval_id: domain-adaptation-on-gtav-synscapes-to
# Matched dataset name: gtav-synscapes-to-cityscapes
# Extracted eval_id: domain-adaptation-on-noisy-amazon-45
# Matched dataset name: noisy-amazon-45
# Extracted eval_id: domain-adaptation-on-usps-to-mnist
# Matched dataset name: usps-to-mnist
# Extracted eval_id: domain-adaptation-on-ucf-to-hmdbfull
# Matched dataset name: ucf-to-hmdbfull
# Extracted eval_id: domain-adaptation-on-gta5-to-cityscapes
# Matched dataset name: gta5-to-cityscapes
# Extracted eval_id: domain-adaptation-on-office-caltech
# Matched dataset name: office-caltech
# Extracted eval_id: domain-adaptation-on-gtav-to-cityscapes-1
# Matched dataset name: gtav-to-cityscapes-mapillary
# Extracted eval_id: domain-adaptation-on-pacs
# Matched dataset name: pacs
# Extracted eval_id: domain-adaptation-on-canon-raw-low-light
# Matched dataset name: canon-raw-low-light
# Extracted eval_id: domain-adaptation-on-mnist-m-to-mnist
# Matched dataset name: mnist-m-to-mnist
# Extracted eval_id: domain-adaptation-on-synth-digits-to-svhn
# Matched dataset name: synth-digits-to-svhn
# Extracted eval_id: domain-adaptation-on-domainnet-1
# Matched dataset name: domainnet
# Extracted eval_id: domain-adaptation-on-synthia-to-cityscapes
# Matched dataset name: synthia-to-cityscapes
# Extracted eval_id: domain-adaptation-on-nikon-raw-low-light
# Matched dataset name: nikon-camera-low-light-raw-image-dataset
# Extracted eval_id: domain-adaptation-on-mnist-to-usps
# Matched dataset name: mnist-to-usps
# Extracted eval_id: domain-adaptation-on-ucf-to-olympic
# Matched dataset name: ucf-to-olympic
# Extracted eval_id: domain-adaptation-on-synscapes-to-cityscapes
# Matched dataset name: synscapes-to-cityscapes
# Extracted eval_id: domain-adaptation-on-cityscapes-to-1
# Matched dataset name: cityscapes-to-foggydriving
# Extracted eval_id: domain-adaptation-on-foggy-cityscapes
# Matched dataset name: foggy-cityscapes
# Extracted eval_id: domain-adaptation-on-ucf-hmdb-full
# Matched dataset name: ucf-hmdb-full-1
# Extracted eval_id: domain-adaptation-on-synth-signs-to-gtsrb
# Matched dataset name: synth-signs-to-gtsrb
# Extracted eval_id: domain-adaptation-on-hmdbfull-to-ucf
# Matched dataset name: hmdbfull-to-ucf
# Extracted eval_id: domain-adaptation-on-tulane
# Matched dataset name: tulane
# Extracted eval_id: domain-adaptation-on-office-31
# Matched dataset name: office-31
# Extracted eval_id: domain-adaptation-on-rotating-mnist
# Matched dataset name: rotating-mnist
# Extracted eval_id: domain-adaptation-on-comic2k
# Matched dataset name: comic2k
# Extracted eval_id: domain-adaptation-on-gta5-synscapes-to
# Matched dataset name: gta5-synscapes-to-cityscapes
# Extracted eval_id: domain-adaptation-on-office-caltech-10
# Matched dataset name: office-caltech-10
# Extracted eval_id: domain-adaptation-on-synthia-to-cityscapes-1
# Matched dataset name: synthia-to-cityscapes-labels
# Extracted eval_id: domain-adaptation-on-olympic-to-hmdbsmall
# Matched dataset name: olympic-to-hmdbsmall
# Extracted eval_id: domain-adaptation-on-sim10k
# Matched dataset name: sim10k
# Extracted eval_id: domain-adaptation-on-molane
# Matched dataset name: molane
# Extracted eval_id: domain-adaptation-on-synsig-to-gtsrb
# Matched dataset name: synsig-to-gtsrb
# Extracted eval_id: domain-adaptation-on-cityscapes-to-acdc
# Matched dataset name: cityscapes-to-acdc
# Extracted eval_id: domain-adaptation-on-hmdb-ucf-full
# Matched dataset name: hmdb-ucf-full
# Extracted eval_id: domain-adaptation-on-synth-objects-to-linemod
# Matched dataset name: synth-objects-to-linemod
# Extracted eval_id: domain-adaptation-on-mulane
# Matched dataset name: mulane
# Extracted eval_id: domain-adaptation-on-gta-to-foggycityscapes
# Matched dataset name: gta-to-foggycityscapes
# Extracted eval_id: domain-adaptation-on-mnist-to-mnist-m
# Matched dataset name: mnist-to-mnist-m
# Extracted eval_id: domain-adaptation-on-cityscapes-to
# Matched dataset name: cityscapes-to-foggyzurich
# Extracted eval_id: domain-adaptation-on-msda
# Matched dataset name: msda
# Extracted eval_id: domain-adaptation-on-svhn-to-mnist
# Matched dataset name: svhn-to-mnist
# Extracted eval_id: domain-adaptation-on-hmdbsmall-to-ucf
# Matched dataset name: hmdbsmall-to-ucf
# Extracted eval_id: domain-adaptation-on-svnh-to-mnist
# Matched dataset name: svnh-to-mnist
# Extracted eval_id: domain-adaptation-on-panoptic-synthia-to-1
# Matched dataset name: panoptic-synthia-to-mapillary
# Extracted eval_id: domain-adaptation-on-noisy-synd-to-mnist
# Matched dataset name: noisy-synd-to-mnist
# Extracted eval_id: sentence-embeddings-for-biomedical-texts-on-4
# Matched dataset name: annotated-corpus-for-semantic-similarity-of
# Extracted eval_id: sentence-embeddings-for-biomedical-texts-on-3
# Matched dataset name: annotated-corpus-for-semantic-similarity-of-1
# Extracted eval_id: sentence-embeddings-for-biomedical-texts-on
# Matched dataset name: biosses
# Extracted eval_id: sentence-embeddings-for-biomedical-texts-on-2
# Matched dataset name: medsts
# Extracted eval_id: zero-shot-learning-on-awa2
# Matched dataset name: awa2-1
# Extracted eval_id: zero-shot-learning-on-lsmdc
# Matched dataset name: lsmdc
# Extracted eval_id: zero-shot-learning-on-snips
# Matched dataset name: snips
# Extracted eval_id: zero-shot-learning-on-cub-200-2011
# Matched dataset name: cub-200-2011
# Extracted eval_id: zero-shot-learning-on-cifar-100
# Matched dataset name: cifar-100
# Extracted eval_id: zero-shot-learning-on-cub-200-0-shot-learning-1
# Matched dataset name: cub-200-0-shot-learning
# Extracted eval_id: zero-shot-learning-on-flowers-102
# Matched dataset name: flowers-102
# Extracted eval_id: zero-shot-learning-on-caltech-101
# Matched dataset name: caltech-101
# Extracted eval_id: zero-shot-learning-on-fgvc-aircraft
# Matched dataset name: fgvc-aircraft-1
# Extracted eval_id: zero-shot-learning-on-eurosat
# Matched dataset name: eurosat
# Extracted eval_id: zero-shot-learning-on-ivqa
# Matched dataset name: ivqa
# Extracted eval_id: zero-shot-learning-on-sun-attribute
# Matched dataset name: sun-attribute
# Extracted eval_id: zero-shot-learning-on-ucf101
# Matched dataset name: ucf101
# Extracted eval_id: zero-shot-learning-on-tvqa
# Matched dataset name: tvqa
# Extracted eval_id: zero-shot-learning-on-stanford-cars
# Matched dataset name: stanford-cars
# Extracted eval_id: zero-shot-learning-on-voc-mlt
# Matched dataset name: voc-mlt
# Extracted eval_id: zero-shot-learning-on-food-101
# Matched dataset name: food-101
# Extracted eval_id: zero-shot-learning-on-pascal-context
# Matched dataset name: pascal-context
# Extracted eval_id: zero-shot-learning-on-cifar-10
# Matched dataset name: cifar-10
# Extracted eval_id: zero-shot-learning-on-oxford-102-flower
# Matched dataset name: oxford-102-flower
# Extracted eval_id: zero-shot-learning-on-coco-mlt
# Matched dataset name: coco-mlt
# Extracted eval_id: zero-shot-learning-on-apy-0-shot
# Matched dataset name: apy-0-shot
# Extracted eval_id: zero-shot-learning-on-sun397
# Matched dataset name: sun397
# Extracted eval_id: zero-shot-learning-on-imagenet
# Matched dataset name: imagenet
# Extracted eval_id: zero-shot-learning-on-msrvtt-qa
# Matched dataset name: msrvtt-qa
# Extracted eval_id: zero-shot-learning-on-imagenet-cn
# Matched dataset name: imagenet-cn
# Extracted eval_id: zero-shot-learning-on-msvd-qa
# Matched dataset name: msvd-qa
# Extracted eval_id: zero-shot-learning-on-dtd
# Matched dataset name: dtd
# Extracted eval_id: zero-shot-learning-on-mit-states-1
# Matched dataset name: mit-states
# Extracted eval_id: zero-shot-learning-on-medconceptsqa
# Matched dataset name: medconceptsqa
# Extracted eval_id: zero-shot-learning-on-how2qa
# Matched dataset name: how2qa
# Extracted eval_id: zero-shot-learning-on-oxford-iiit-pets
# Matched dataset name: oxford-iiit-pets-1
# Extracted eval_id: anomaly-detection-on-voraus-ad
# Matched dataset name: voraus-ad
# Extracted eval_id: anomaly-detection-on-ucsd-ped2
# Matched dataset name: ucsd
# Extracted eval_id: anomaly-detection-on-mnist-test
# Matched dataset name: mnist-test
# Extracted eval_id: anomaly-detection-on-cats-and-dogs
# Matched dataset name: cats-and-dogs
# Extracted eval_id: anomaly-detection-on-mit-bih-arrhythmia
# Matched dataset name: mit-bih-arrhythmia-database
# Extracted eval_id: anomaly-detection-on-real-3d-ad
# Matched dataset name: real-3d-ad
# Extracted eval_id: anomaly-detection-on-musk-v1
# Matched dataset name: musk-v1
# Extracted eval_id: anomaly-detection-on-mvtec-ad-textures-domain
# Matched dataset name: mvtec-ad-textures-domain-generalization
# Extracted eval_id: anomaly-detection-on-unlabeled-cifar-10-vs
# Matched dataset name: unlabeled-cifar-10-vs-cifar-100
# Extracted eval_id: anomaly-detection-on-numenta-anomaly
# Matched dataset name: numenta-anomaly-benchmark
# Extracted eval_id: anomaly-detection-on-fishyscapes-l-f
# Matched dataset name: fishyscapes-l-f
# Extracted eval_id: anomaly-detection-on-odds
# Matched dataset name: odds
# Extracted eval_id: anomaly-detection-on-thyroid
# Matched dataset name: thyroid
# Extracted eval_id: anomaly-detection-on-leave-one-class-out
# Matched dataset name: leave-one-class-out-cifar-10
# Extracted eval_id: anomaly-detection-on-nb15-dos
# Matched dataset name: nb15-dos
# Extracted eval_id: anomaly-detection-on-cifar-10
# Matched dataset name: cifar-10
# Extracted eval_id: anomaly-detection-on-ksdd2
# Matched dataset name: ksdd2
# Extracted eval_id: anomaly-detection-on-aebad-v
# Matched dataset name: aebad-v
# Extracted eval_id: anomaly-detection-on-ucsd-peds2
# Matched dataset name: ucsd-peds2
# Extracted eval_id: anomaly-detection-on-btad
# Matched dataset name: btad
# Extracted eval_id: anomaly-detection-on-fashion-mnist
# Matched dataset name: fashion-mnist
# Extracted eval_id: anomaly-detection-on-uea-time-series-datasets
# Matched dataset name: uea-time-series-datasets
# Extracted eval_id: anomaly-detection-on-pad-dataset
# Matched dataset name: pose-agnostic-anomaly-detection-dataset
# Extracted eval_id: anomaly-detection-on-mvtec-3d-ad-1
# Matched dataset name: mvtec-3d-ad
# Extracted eval_id: anomaly-detection-on-vehicle-claims
# Matched dataset name: vehicle-claims
# Extracted eval_id: anomaly-detection-on-mvtec-ad
# Matched dataset name: mvtec-ad
# Extracted eval_id: anomaly-detection-on-leave-one-class-out-1
# Matched dataset name: leave-one-class-out-imagenet-30
# Extracted eval_id: anomaly-detection-on-hyper-kvasir-dataset
# Matched dataset name: hyper-kvasir-dataset
# Extracted eval_id: anomaly-detection-on-ubnormal
# Matched dataset name: ubnormal
# Extracted eval_id: anomaly-detection-on-lag
# Matched dataset name: lag
# Extracted eval_id: anomaly-detection-on-visa
# Matched dataset name: visa
# Extracted eval_id: anomaly-detection-on-anomaly-detection-on-2
# Matched dataset name: anomaly-detection-on-anomaly-detection-on
# Extracted eval_id: anomaly-detection-on-kdd-cup-1999
# Matched dataset name: kdd-cup-1999-data-data-set
# Extracted eval_id: anomaly-detection-on-forest-covertype
# Matched dataset name: forest-covertype
# Extracted eval_id: anomaly-detection-on-kaggle-credit-card-fraud
# Matched dataset name: kaggle-credit-card-fraud-dataset
# Extracted eval_id: anomaly-detection-on-dior
# Matched dataset name: dior
# Extracted eval_id: anomaly-detection-on-census
# Matched dataset name: census
# Extracted eval_id: anomaly-detection-on-mvtec-loco-ad
# Matched dataset name: mvtec-loco-ad
# Extracted eval_id: anomaly-detection-on-one-class-imagenet-30
# Matched dataset name: one-class-imagenet-30
# Extracted eval_id: anomaly-detection-on-assira-cat-vs-dog
# Matched dataset name: assira-cat-vs-dog
# Extracted eval_id: anomaly-detection-on-anomaly-detection-on-1
# Matched dataset name: anomaly-detection-on-unlabeled-imagenet-30-vs
# Extracted eval_id: anomaly-detection-on-lost-and-found
# Matched dataset name: lost-and-found
# Extracted eval_id: anomaly-detection-on-one-class-cifar-100
# Matched dataset name: one-class-cifar-100
# Extracted eval_id: anomaly-detection-on-stl-10
# Matched dataset name: stl-10
# Extracted eval_id: anomaly-detection-on-bottlecap
# Matched dataset name: bottlecap
# Extracted eval_id: anomaly-detection-on-mvtec-ad-textures
# Matched dataset name: mvtec-ad-textures
# Extracted eval_id: anomaly-detection-on-surface-defect-saliency
# Matched dataset name: surface-defect-saliency-of-magnetic-tile
# Extracted eval_id: anomaly-detection-on-insplad
# Matched dataset name: insplad
# Extracted eval_id: anomaly-detection-on-one-class-cifar-10
# Matched dataset name: one-class-cifar-10
# Extracted eval_id: anomaly-detection-on-shanghaitech
# Matched dataset name: shanghaitech
# Extracted eval_id: anomaly-detection-on-nb15-backdoor
# Matched dataset name: nb15-backdoor
# Extracted eval_id: anomaly-detection-on-corridor
# Matched dataset name: corridor
# Extracted eval_id: anomaly-detection-on-aebad-s
# Matched dataset name: aebad-s
# Extracted eval_id: anomaly-detection-on-tii-ssrc-23
# Matched dataset name: tii-ssrc-23
# Extracted eval_id: anomaly-detection-on-mnist
# Matched dataset name: mnist
# Extracted eval_id: anomaly-detection-on-road-anomaly
# Matched dataset name: road-anomaly
# Extracted eval_id: anomaly-detection-on-adni
# Matched dataset name: adni
# Extracted eval_id: anomaly-detection-on-ag-news
# Matched dataset name: ag-news
# Extracted eval_id: anomaly-detection-on-anomaly-detection-on
# Matched dataset name: anomaly-detection-on-unlabeled-cifar-10-vs
# Extracted eval_id: anomaly-detection-on-svhn
# Matched dataset name: svhn
# Extracted eval_id: anomaly-detection-on-kdd-99
# Matched dataset name: kdd-99
# Extracted eval_id: anomaly-detection-on-nb15-analysis
# Matched dataset name: nb15-analysis
# Extracted eval_id: anomaly-detection-on-fishyscapes-1
# Matched dataset name: fishyscapes
# Extracted eval_id: anomaly-detection-on-mvtec-3d-ad-rgb
# Matched dataset name: mvtec-3d-ad-rgb
# Extracted eval_id: anomaly-detection-on-coco-ooc
# Matched dataset name: coco-ooc
# Extracted eval_id: anomaly-detection-on-chuk-avenue
# Matched dataset name: chuk-avenue
# Extracted eval_id: anomaly-detection-on-ucf-crime-1
# Matched dataset name: ucf-crime
# Extracted eval_id: meta-learning-on-ml10
# Matched dataset name: ml10
# Extracted eval_id: meta-learning-on-ml45
# Matched dataset name: ml45
# Extracted eval_id: meta-learning-on-omniglot-1-shot-20-way
# Matched dataset name: omniglot-1-shot-20-way
# Extracted eval_id: meta-learning-on-mt50
# Matched dataset name: mt50
# Extracted eval_id: multimodal-text-and-image-classification-on-1
# Matched dataset name: food-101
# Extracted eval_id: multimodal-text-and-image-classification-on
# Matched dataset name: cub-200-2011
# Extracted eval_id: multimodal-text-and-image-classification-on-2
# Matched dataset name: cd18
# Extracted eval_id: metric-learning-on-cub-200-2011
# Matched dataset name: cub-200-2011-1
# Extracted eval_id: metric-learning-on-cars196
# Matched dataset name: cars196
# Extracted eval_id: metric-learning-on-dyml-product
# Matched dataset name: dyml-product
# Extracted eval_id: metric-learning-on-dyml-vehicle
# Matched dataset name: dyml-vehicle
# Extracted eval_id: metric-learning-on-cub-200-2011-4
# Matched dataset name: cub-200-2011
# Extracted eval_id: metric-learning-on-in-shop-1
# Matched dataset name: in-shop
# Extracted eval_id: metric-learning-on-dyml-animal
# Matched dataset name: dyml-animal
# Extracted eval_id: metric-learning-on-stanford-online-products-1
# Matched dataset name: stanford-online-products
# Extracted eval_id: multi-label-classification-on-nus-wide
# Matched dataset name: nus-wide
# Extracted eval_id: multi-label-classification-on-chexpert
# Matched dataset name: chexpert
# Extracted eval_id: multi-label-classification-on-mrnet
# Matched dataset name: mrnet
# Extracted eval_id: multi-label-classification-on-chestx-ray14
# Matched dataset name: chestx-ray14
# Extracted eval_id: multi-label-classification-on-openimages-v6
# Matched dataset name: openimages-v6
# Extracted eval_id: multi-label-classification-on-ms-coco
# Matched dataset name: ms-coco
# Extracted eval_id: multi-label-classification-on-pascal-voc-2007
# Matched dataset name: pascal-voc-2007
# Extracted eval_id: multi-label-classification-on-pascal-voc-2012
# Matched dataset name: pascal-voc-2012
# Extracted eval_id: multi-label-classification-on-mimic-cxr
# Matched dataset name: mimic-cxr
# Extracted eval_id: multi-label-classification-on-mlrsnet
# Matched dataset name: mlrsnet
# Extracted eval_id: unsupervised-pre-training-on-uci-measles
# Matched dataset name: uci-measles
# Extracted eval_id: unsupervised-pre-training-on-measles
# Matched dataset name: measles
# Extracted eval_id: core-set-discovery-on-credit-g
# Matched dataset name: credit-g
# Extracted eval_id: core-set-discovery-on-letter
# Matched dataset name: letter
# Extracted eval_id: core-set-discovery-on-micro-mass
# Matched dataset name: micro-mass
# Extracted eval_id: core-set-discovery-on-electricity
# Matched dataset name: electricity
# Extracted eval_id: core-set-discovery-on-glass-identification
# Matched dataset name: glass-identification
# Extracted eval_id: core-set-discovery-on-isolet
# Matched dataset name: isolet
# Extracted eval_id: core-set-discovery-on-amazon-employee-access
# Matched dataset name: amazon-employee-access
# Extracted eval_id: core-set-discovery-on-mozilla4
# Matched dataset name: mozilla4
# Extracted eval_id: core-set-discovery-on-abalone
# Matched dataset name: abalone
# Extracted eval_id: core-set-discovery-on-mnist
# Matched dataset name: mnist
# Extracted eval_id: core-set-discovery-on-jm1
# Matched dataset name: jm1
# Extracted eval_id: core-set-discovery-on-kr-vs-kp
# Matched dataset name: kr-vs-kp
# Extracted eval_id: core-set-discovery-on-soybean
# Matched dataset name: soybean
# Extracted eval_id: core-set-discovery-on-uci-gas
# Matched dataset name: uci-gas
# Extracted eval_id: clustering-algorithms-evaluation-on-97
# Matched dataset name: 97-synthetic-datasets
# Extracted eval_id: clustering-algorithms-evaluation-on-pathbased
# Matched dataset name: pathbased
# Extracted eval_id: clustering-algorithms-evaluation-on-fashion-2
# Matched dataset name: fashion-mnist
# Extracted eval_id: clustering-algorithms-evaluation-on-olivetti
# Matched dataset name: olivetti-face
# Extracted eval_id: clustering-algorithms-evaluation-on-mnist
# Matched dataset name: mnist
# Extracted eval_id: clustering-algorithms-evaluation-on
# Matched dataset name: ionosphere
# Extracted eval_id: clustering-algorithms-evaluation-on-iris
# Matched dataset name: iris-1
# Extracted eval_id: clustering-algorithms-evaluation-on-jaffe
# Matched dataset name: jaffe
# Extracted eval_id: clustering-algorithms-evaluation-on-seeds
# Matched dataset name: seeds
# Extracted eval_id: clustering-algorithms-evaluation-on-pixraw10p
# Matched dataset name: pixraw10p
# Extracted eval_id: 3d-anomaly-detection-and-segmentation-on
# Matched dataset name: mvtec-3d-ad
# Extracted eval_id: structured-prediction-on-mnist
# Matched dataset name: mnist
# Extracted eval_id: unsupervised-mnist-on-mnist
# Matched dataset name: mnist
# Extracted eval_id: anomaly-detection-in-surveillance-videos-on
# Matched dataset name: ucf-crime
# Extracted eval_id: anomaly-detection-in-surveillance-videos-on-3
# Matched dataset name: ucsd-peds2
# Extracted eval_id: anomaly-detection-in-surveillance-videos-on-2
# Matched dataset name: xd-violence
# Extracted eval_id: anomaly-detection-in-surveillance-videos-on-5
# Matched dataset name: vfp290k
# Extracted eval_id: anomaly-detection-in-surveillance-videos-on-1
# Matched dataset name: shanghaitech-weakly-supervised
# Extracted eval_id: quantization-on-knowledge-based
# Matched dataset name: knowledge-based
# Extracted eval_id: quantization-on-cifar-10
# Matched dataset name: cifar-10
# Extracted eval_id: quantization-on-ijb-c
# Matched dataset name: ijb-c
# Extracted eval_id: quantization-on-wiki-40b
# Matched dataset name: wiki-40b
# Extracted eval_id: quantization-on-imagenet
# Matched dataset name: imagenet
# Extracted eval_id: quantization-on-agedb-30
# Matched dataset name: agedb-30
# Extracted eval_id: quantization-on-ijb-b
# Matched dataset name: ijb-b
# Extracted eval_id: quantization-on-lfw
# Matched dataset name: lfw
# Extracted eval_id: quantization-on-cfp-fp
# Matched dataset name: cfp-fp
# Extracted eval_id: quantization-on-coco
# Matched dataset name: coco
# Extracted eval_id: incremental-constrained-clustering-on-wine
# Matched dataset name: wine
# Extracted eval_id: incremental-constrained-clustering-on-iris
# Matched dataset name: iris-1
# Extracted eval_id: face-quality-assessement-on-color-feret
# Matched dataset name: color-feret
# Extracted eval_id: face-quality-assessement-on-lfw
# Matched dataset name: lfw
# Extracted eval_id: face-quality-assessement-on-adience
# Matched dataset name: adience
# Extracted eval_id: feature-engineering-on-2019-test-set-1
# Matched dataset name: 2019-test-set
# Extracted eval_id: domain-generalization-on-imagenet-c
# Matched dataset name: imagenet-c
# Extracted eval_id: domain-generalization-on-vlcs
# Matched dataset name: vlcs
# Extracted eval_id: domain-generalization-on-nico-animal
# Matched dataset name: nico-animal
# Extracted eval_id: domain-generalization-on-nico-vehicle
# Matched dataset name: nico-vehicle
# Extracted eval_id: domain-generalization-on-domainnet
# Matched dataset name: domainnet
# Extracted eval_id: domain-generalization-on-rotated-fashion
# Matched dataset name: rotated-fashion-mnist
# Extracted eval_id: domain-generalization-on-gta-to-avg
# Matched dataset name: gta-to-avg-cityscapes-bdd-mapillary
# Extracted eval_id: domain-generalization-on-wilddash
# Matched dataset name: wilddash
# Extracted eval_id: domain-generalization-on-stylized-imagenet
# Matched dataset name: stylized-imagenet-1
# Extracted eval_id: domain-generalization-on-gta5-to-cityscapes
# Matched dataset name: gta5-to-cityscapes-1
# Extracted eval_id: domain-generalization-on-lipitk
# Matched dataset name: lipitk
# Extracted eval_id: domain-generalization-on-pacs-2
# Matched dataset name: pacs
# Extracted eval_id: domain-generalization-on-imagenet-r
# Matched dataset name: imagenet-r
# Extracted eval_id: domain-generalization-on-terraincognita
# Matched dataset name: terraincognita
# Extracted eval_id: domain-generalization-on-vizwiz
# Matched dataset name: vizwiz-classification
# Extracted eval_id: domain-generalization-on-office-home
# Matched dataset name: office-home
# Extracted eval_id: domain-generalization-on-imagenet-a
# Matched dataset name: imagenet-a
# Extracted eval_id: domain-generalization-on-imagenet-sketch
# Matched dataset name: imagenet-sketch
# Extracted eval_id: generalized-zero-shot-learning-on-scannet
# Matched dataset name: scannet
# Extracted eval_id: generalized-zero-shot-learning-on-sun
# Matched dataset name: sun-attribute
# Extracted eval_id: generalized-zero-shot-learning-on-apy-0-shot
# Matched dataset name: apy-0-shot
# Extracted eval_id: generalized-zero-shot-learning-on-ontonotes
# Matched dataset name: ontonotes
# Extracted eval_id: generalized-zero-shot-learning-on-caltech
# Matched dataset name: caltech-ucsd-birds-200-2011
# Extracted eval_id: generalized-zero-shot-learning-on-bbn-pronoun
# Matched dataset name: bbn-pronoun-coreference-and-entity-type
# Extracted eval_id: generalized-zero-shot-learning-on-oxford-102-1
# Matched dataset name: oxford-102-flower
# Extracted eval_id: generalized-zero-shot-learning-on-s3dis
# Matched dataset name: s3dis
# Extracted eval_id: generalized-zero-shot-learning-on-cub-200
# Matched dataset name: cub-200-2011
# Extracted eval_id: generalized-zero-shot-learning-on
# Matched dataset name: semantickitti
# Extracted eval_id: generalized-zero-shot-learning-on-apy
# Matched dataset name: apy
# Extracted eval_id: generalized-zero-shot-learning-on-awa2
# Matched dataset name: awa2-1
# Extracted eval_id: one-shot-learning-on-mnist
# Matched dataset name: mnist
# Extracted eval_id: machine-learning-on-big-bench
# Matched dataset name: big-bench
# Extracted eval_id: abnormal-event-detection-in-video-on-ucsd
# Matched dataset name: ucsd
# Extracted eval_id: abnormal-event-detection-in-video-on-ubi
# Matched dataset name: ubi-fights
# ...
# Extracted eval_id: nested-named-entity-recognition-on-ace-2004
# Matched dataset name: ace-2004
# Extracted eval_id: nested-named-entity-recognition-on-ace-2005
# Matched dataset name: ace-2005
# Extracted eval_id: discourse-marker-prediction-on-big-bench
# Matched dataset name: big-bench
# Extracted eval_id: medical-named-entity-recognition-on-share-1
# Matched dataset name: share-clef-2014-task-2-disorders-1
# Extracted eval_id: medical-named-entity-recognition-on-share
# Matched dataset name: share-clef-ehealth-corpus
# Extracted eval_id: grammatical-error-detection-on-fce
# Matched dataset name: fce
# Extracted eval_id: grammatical-error-detection-on-conll-2014-a1
# Matched dataset name: conll-2014-a1
# Extracted eval_id: grammatical-error-detection-on-conll-2014-a2
# Matched dataset name: conll-2014-a2
# Extracted eval_id: grammatical-error-detection-on-jfleg
# Matched dataset name: jfleg
# Extracted eval_id: summarization-on-samsum-1
# Matched dataset name: samsum-corpus
# Extracted eval_id: summarization-on-scientific-papers
# Matched dataset name: scientific-papers
# Extracted eval_id: summarization-on-cnn-dailymail
# Matched dataset name: cnn-dailymail
# Extracted eval_id: summarization-on-muld-vlsp
# Matched dataset name: muld-vlsp
# Extracted eval_id: summarization-on-xsum
# Matched dataset name: xsum
# Extracted eval_id: summarization-on-mlsum-de
# Matched dataset name: mlsum-de
# Extracted eval_id: summarization-on-bazzhangz-sumdataset
# Matched dataset name: bazzhangz-sumdataset
# Extracted eval_id: binary-condescension-detection-on-dpm
# Matched dataset name: dpm
# Extracted eval_id: fine-grained-opinion-analysis-on-mpqa
# Matched dataset name: mpqa
# Extracted eval_id: legal-reasoning-on-legalbench-issue-spotting
# Matched dataset name: legalbench-issue-spotting
# Extracted eval_id: legal-reasoning-on-legalbench-rule-recall
# Matched dataset name: legalbench-rule-recall
# Extracted eval_id: language-acquisition-on-slam-2018
# Matched dataset name: slam-2018
# Extracted eval_id: hope-speech-detection-on-hopeedi
# Matched dataset name: hopeedi
# Extracted eval_id: hope-speech-detection-on-kanhope
# Matched dataset name: kanhope
# Extracted eval_id: text-to-video-generation-on-evalcrafter-text
# Matched dataset name: evalcrafter-text-to-video-ectv-dataset
# Extracted eval_id: text-to-video-generation-on-kinetics
# Matched dataset name: kinetics
# Extracted eval_id: text-to-video-generation-on-msr-vtt
# Matched dataset name: msr-vtt
# Extracted eval_id: text-to-video-generation-on-webvid
# Matched dataset name: webvid
# Extracted eval_id: text-to-video-generation-on-ucf-101
# Matched dataset name: ucf-101
# Extracted eval_id: text-to-video-generation-on-something
# Matched dataset name: something-something-v2
# Extracted eval_id: meeting-summarization-on-icsi-meeting-corpus
# Matched dataset name: icsi-meeting-corpus
# Extracted eval_id: meeting-summarization-on-ami-meeting-corpus
# Matched dataset name: ami-meeting-corpus
# Extracted eval_id: semantic-textual-similarity-on-sts16
# Matched dataset name: sts16
# Extracted eval_id: semantic-textual-similarity-on-senteval
# Matched dataset name: senteval
# Extracted eval_id: semantic-textual-similarity-on-cxc
# Matched dataset name: cxc
# Extracted eval_id: semantic-textual-similarity-on-sick
# Matched dataset name: sick
# Extracted eval_id: semantic-textual-similarity-on-sts-benchmark
# Matched dataset name: sts-benchmark
# Extracted eval_id: semantic-textual-similarity-on-sts15
# Matched dataset name: sts15
# Extracted eval_id: semantic-textual-similarity-on-sts12
# Matched dataset name: sts12
# Extracted eval_id: semantic-textual-similarity-on-mteb
# Matched dataset name: mteb
# Extracted eval_id: semantic-textual-similarity-on-sts13
# Matched dataset name: sts13
# Extracted eval_id: semantic-textual-similarity-on-sts14
# Matched dataset name: sts14
# Extracted eval_id: semantic-textual-similarity-on-mrpc
# Matched dataset name: mrpc
# Extracted eval_id: semantic-textual-similarity-on-mrpc-dev
# Matched dataset name: mrpc-dev
# Extracted eval_id: semantic-textual-similarity-on-sick-r-1
# Matched dataset name: sick-r
# Extracted eval_id: implicit-relations-on-big-bench
# Matched dataset name: big-bench
# Extracted eval_id: entity-disambiguation-on-msnbc
# Matched dataset name: msnbc
# Extracted eval_id: entity-disambiguation-on-wned-wiki
# Matched dataset name: wned-wiki
# Extracted eval_id: entity-disambiguation-on-shadowlink-shadow
# Matched dataset name: shadowlink-shadow
# Extracted eval_id: entity-disambiguation-on-aida-conll
# Matched dataset name: aida-conll
# Extracted eval_id: entity-disambiguation-on-ace2004
# Matched dataset name: ace2004
# Extracted eval_id: entity-disambiguation-on-tac2010
# Matched dataset name: tac2010
# Extracted eval_id: entity-disambiguation-on-aquaint
# Matched dataset name: aquaint
# Extracted eval_id: entity-disambiguation-on-mewsli-9
# Matched dataset name: mewsli-9
# Extracted eval_id: entity-disambiguation-on-docred-ie
# Matched dataset name: docred-ie
# Extracted eval_id: entity-disambiguation-on-shadowlink-top
# Matched dataset name: shadowlink-top
# Extracted eval_id: entity-disambiguation-on-wned-cweb
# Matched dataset name: wned-cweb
# Extracted eval_id: timeline-summarization-on-mts
# Matched dataset name: mts
# Extracted eval_id: dialog-relation-extraction-on-ddrel
# Matched dataset name: ddrel
# Extracted eval_id: dialog-relation-extraction-on-dialogre
# Matched dataset name: dialogre
# Extracted eval_id: multimodal-abstractive-text-summarization-on
# Matched dataset name: how2-300h
# Extracted eval_id: multimodal-machine-translation-on-multi30k
# Matched dataset name: multi30k
# Extracted eval_id: multimodal-machine-translation-on-hindi-1
# Matched dataset name: hindi-visual-genome-test-set
# Extracted eval_id: multimodal-machine-translation-on-hindi-2
# Matched dataset name: hindi-visual-genome-challenge-set
# Extracted eval_id: counterspeech-detection-on-youtube
# Matched dataset name: youtube-counterspeech-dataset
# Extracted eval_id: fantasy-reasoning-on-big-bench
# Matched dataset name: big-bench
# Extracted eval_id: emotion-cause-pair-extraction-on-ecpe
# Matched dataset name: ecpe
# Extracted eval_id: emotion-cause-pair-extraction-on-ecpe-1
# Matched dataset name: ecpe-fansplit
# Extracted eval_id: zero-shot-relation-triplet-extraction-on
# Matched dataset name: fewrel
# Extracted eval_id: zero-shot-relation-triplet-extraction-on-wiki
# Matched dataset name: wiki-zsl
# Extracted eval_id: gre-reading-comprehension-on-big-bench
# Matched dataset name: big-bench
# Extracted eval_id: prompt-engineering-on-imagenet-21k
# Matched dataset name: imagenet-21k
# Extracted eval_id: prompt-engineering-on-imagenet-a
# Matched dataset name: imagenet-a
# Extracted eval_id: prompt-engineering-on-oxford-iiit-pet-dataset
# Matched dataset name: oxford-iiit-pets
# Extracted eval_id: prompt-engineering-on-fgvc-aircraft
# Matched dataset name: fgvc-aircraft-1
# Extracted eval_id: prompt-engineering-on-imagenet-s
# Matched dataset name: imagenet-s
# Extracted eval_id: prompt-engineering-on-sun397
# Matched dataset name: sun397
# Extracted eval_id: prompt-engineering-on-eurosat
# Matched dataset name: eurosat
# Extracted eval_id: prompt-engineering-on-dtd
# Matched dataset name: dtd
# Extracted eval_id: prompt-engineering-on-imagenet-r
# Matched dataset name: imagenet-r
# Extracted eval_id: prompt-engineering-on-imagenet-v2
# Matched dataset name: imagenet-v2
# Extracted eval_id: prompt-engineering-on-stanford-cars-1
# Matched dataset name: stanford-cars
# Extracted eval_id: prompt-engineering-on-ucf101
# Matched dataset name: ucf101
# Extracted eval_id: prompt-engineering-on-oxford-102-flower
# Matched dataset name: oxford-102-flower
# Extracted eval_id: prompt-engineering-on-caltech-101
# Matched dataset name: caltech-101
# Extracted eval_id: prompt-engineering-on-food-101
# Matched dataset name: food-101
# Extracted eval_id: prompt-engineering-on-imagenet
# Matched dataset name: imagenet
# Extracted eval_id: topic-coverage-on-topic-modeling-topic-1
# Matched dataset name: topic-modeling-topic-coverage-dataset-bio
# Extracted eval_id: topic-coverage-on-topic-modeling-topic-2
# Matched dataset name: topic-modeling-topic-coverage-dataset
# Extracted eval_id: topic-coverage-on-topic-modeling-topic
# Matched dataset name: topic-modeling-topic-coverage-dataset-news
# Extracted eval_id: open-domain-question-answering-on-squad11
# Matched dataset name: squad1-1
# Extracted eval_id: open-domain-question-answering-on
# Matched dataset name: webquestions
# Extracted eval_id: open-domain-question-answering-on-natural
# Matched dataset name: natural-questions
# Extracted eval_id: open-domain-question-answering-on-quasar
# Matched dataset name: quasar
# Extracted eval_id: open-domain-question-answering-on-kilt
# Matched dataset name: kilt-natural-questions
# Extracted eval_id: open-domain-question-answering-on-triviaqa
# Matched dataset name: triviaqa
# Extracted eval_id: open-domain-question-answering-on-searchqa
# Matched dataset name: searchqa
# Extracted eval_id: open-domain-question-answering-on-kilt-2
# Matched dataset name: kilt-triviaqa
# Extracted eval_id: open-domain-question-answering-on-eli5
# Matched dataset name: eli5
# Extracted eval_id: open-domain-question-answering-on-kilt-eli5
# Matched dataset name: kilt-eli5
# Extracted eval_id: open-domain-question-answering-on-kilt-1
# Matched dataset name: kilt-hotpotqa
# Extracted eval_id: open-domain-question-answering-on-natural-1
# Matched dataset name: natural-questions-short
# Extracted eval_id: open-domain-question-answering-on-dureader
# Matched dataset name: dureader
# Extracted eval_id: open-domain-question-answering-on-squad1-1
# Matched dataset name: squad1-1-dev
# Extracted eval_id: open-domain-question-answering-on-tqa
# Matched dataset name: tqa
# Extracted eval_id: mathematical-reasoning-on-lila-iid
# Matched dataset name: lila-iid
# Extracted eval_id: mathematical-reasoning-on-pgps9k
# Matched dataset name: pgps9k
# Extracted eval_id: mathematical-reasoning-on-mmlu-mathematics
# Matched dataset name: mmlu-mathematics
# Extracted eval_id: mathematical-reasoning-on-lila-ood
# Matched dataset name: lila-ood
# Extracted eval_id: cross-domain-named-entity-recognition-on
# Matched dataset name: conll04
# Extracted eval_id: semeval-2022-task-4-1-binary-pcl-detection-on
# Matched dataset name: dpm
# Extracted eval_id: chemical-indexing-on-bc7-nlm-chem
# Matched dataset name: bc7-nlm-chem
# Extracted eval_id: columns-property-annotation-on-wdc-sotab
# Matched dataset name: wdc-sotab
# Extracted eval_id: columns-property-annotation-on-wikitables
# Matched dataset name: wikitables-turl-cpa
# Extracted eval_id: columns-property-annotation-on-wdc-sotab-v2
# Matched dataset name: wdc-sotab-v2
# Extracted eval_id: columns-property-annotation-on-t2dv2
# Matched dataset name: t2dv2
# Extracted eval_id: question-similarity-on-q2q-arabic-benchmark
# Matched dataset name: q2q-arabic-benchmark
# Extracted eval_id: table-based-fact-verification-on-tabfact
# Matched dataset name: tabfact
# Extracted eval_id: machine-reading-comprehension-on-dream
# Matched dataset name: dream
# Extracted eval_id: machine-reading-comprehension-on-reclor
# Matched dataset name: reclor
# Extracted eval_id: machine-reading-comprehension-on-uquad
# Matched dataset name: uquad
# Extracted eval_id: machine-reading-comprehension-on-biomrc
# Matched dataset name: biomrc
# Extracted eval_id: keyphrase-extraction-on-inspec
# Matched dataset name: inspec
# Extracted eval_id: keyphrase-extraction-on-kptimes
# Matched dataset name: kptimes
# Extracted eval_id: keyphrase-extraction-on-kp20k
# Matched dataset name: kp20k
# Extracted eval_id: keyphrase-extraction-on-semeval2017
# Matched dataset name: semeval2017
# Extracted eval_id: keyphrase-extraction-on-nus
# Matched dataset name: nus
# Extracted eval_id: keyphrase-extraction-on-krapivin
# Matched dataset name: krapivin
# Extracted eval_id: drs-parsing-on-pmb-2-2-0
# Matched dataset name: pmb-2-2-0
# Extracted eval_id: drs-parsing-on-pmb-3-0-0
# Matched dataset name: pmb-3-0-0
# Extracted eval_id: problem-solving-deliberation-on-delidata
# Matched dataset name: delidata
# Extracted eval_id: code-repair-on-codexglue-bugs2fix
# Matched dataset name: codexglue-bugs2fix
# Extracted eval_id: chinese-word-segmentation-on-pku
# Matched dataset name: pku
# Extracted eval_id: chinese-word-segmentation-on-cityu
# Matched dataset name: cityu
# Extracted eval_id: chinese-word-segmentation-on-ctb6
# Matched dataset name: ctb6
# Extracted eval_id: chinese-word-segmentation-on-msra
# Matched dataset name: msra
# Extracted eval_id: chinese-word-segmentation-on-as
# Matched dataset name: as
# Extracted eval_id: chinese-word-segmentation-on-msr
# Matched dataset name: msr
# Extracted eval_id: slot-filling-on-atis
# Matched dataset name: atis
# Extracted eval_id: slot-filling-on-cais
# Matched dataset name: cais
# Extracted eval_id: slot-filling-on-vietnamese-intent-detection
# Matched dataset name: vietnamese-intent-detection-and-slot-filling
# Extracted eval_id: slot-filling-on-massive
# Matched dataset name: massive
# Extracted eval_id: slot-filling-on-kilt-t-rex
# Matched dataset name: kilt-t-rex
# Extracted eval_id: slot-filling-on-mixatis
# Matched dataset name: mixatis
# Extracted eval_id: slot-filling-on-mixsnips
# Matched dataset name: mixsnips
# Extracted eval_id: slot-filling-on-proslu
# Matched dataset name: proslu
# Extracted eval_id: slot-filling-on-kilt-zero-shot-re
# Matched dataset name: kilt-zero-shot-re
# Extracted eval_id: slot-filling-on-snips
# Matched dataset name: snips
# Extracted eval_id: slot-filling-on-polyvore
# Matched dataset name: polyvore
# Extracted eval_id: slot-filling-on-slurp
# Matched dataset name: slurp
# Extracted eval_id: intent-classification-on-slurp
# Matched dataset name: slurp
# Extracted eval_id: intent-classification-on-massive
# Matched dataset name: massive
# Extracted eval_id: intent-classification-on-orcas-i
# Matched dataset name: orcas-i
# Extracted eval_id: intent-classification-on-kuake-qic
# Matched dataset name: kuake-qic
# Extracted eval_id: paper-generation-on-acl-title-and-abstract
# Matched dataset name: acl-title-and-abstract-dataset
# Extracted eval_id: paper-generation-on-2017-robotic-instrument
# Matched dataset name: 2017-robotic-instrument-segmentation
# Extracted eval_id: stance-detection-us-election-2020-trump-on
# Matched dataset name: twitter-stance-election-2020
# Extracted eval_id: claim-evidence-pair-extraction-cepe-on-iam
# Matched dataset name: iam-dataset
# Extracted eval_id: nonsense-words-grammar-on-big-bench
# Matched dataset name: big-bench
# Extracted eval_id: multimodal-sentiment-analysis-on-cmu-mosi
# Matched dataset name: cmu-mosi
# Extracted eval_id: multimodal-sentiment-analysis-on-b-t4sa
# Matched dataset name: b-t4sa
# Extracted eval_id: multimodal-sentiment-analysis-on-cmu-mosei-1
# Matched dataset name: cmu-mosei
# Extracted eval_id: multimodal-sentiment-analysis-on-mosi
# Matched dataset name: mosi
# Extracted eval_id: multimodal-sentiment-analysis-on-ch-sims
# Matched dataset name: ch-sims
# Extracted eval_id: task-oriented-dialogue-systems-on-multiwoz-2
# Matched dataset name: multiwoz-2-0
# Extracted eval_id: task-oriented-dialogue-systems-on-sgd
# Matched dataset name: sgd
# Extracted eval_id: task-oriented-dialogue-systems-on-kvret-1
# Matched dataset name: kvret
# Extracted eval_id: task-oriented-dialogue-systems-on-kvret
# Matched dataset name: kvret-1
# Evaluations DataFrame:
#                                        Task      Dataset              Metric  \
# 0  depth-anomaly-detection-and-segmentation  mvtec-3d-ad  Segmentation AUPRO
# 1  depth-anomaly-detection-and-segmentation  mvtec-3d-ad     Detection AUROC
# 2  depth-anomaly-detection-and-segmentation  mvtec-3d-ad  Segmentation AUROC
# 3  depth-anomaly-detection-and-segmentation  mvtec-3d-ad  Segmentation AUPRO
# 4  depth-anomaly-detection-and-segmentation  mvtec-3d-ad     Detection AUROC
#
#     Value         Model                                        Paper  \
# 0  0.9293  CPMF (2D+3D)  complementary-pseudo-multimodal-feature-for
# 1  0.9515  CPMF (2D+3D)  complementary-pseudo-multimodal-feature-for
# 2  0.9781  CPMF (2D+3D)  complementary-pseudo-multimodal-feature-for
# 3  0.9230     CPMF (3D)  complementary-pseudo-multimodal-feature-for
# 4  0.8304     CPMF (3D)  complementary-pseudo-multimodal-feature-for
#
#          Date
# 0  2023-03-23
# 1  2023-03-23
# 2  2023-03-23
# 3  2023-03-23
# 4  2023-03-23

# %%
evaluations_df
# Out:
#                                             Task      Dataset  \
# 0       depth-anomaly-detection-and-segmentation  mvtec-3d-ad
# 1       depth-anomaly-detection-and-segmentation  mvtec-3d-ad
# 2       depth-anomaly-detection-and-segmentation  mvtec-3d-ad
# 3       depth-anomaly-detection-and-segmentation  mvtec-3d-ad
# 4       depth-anomaly-detection-and-segmentation  mvtec-3d-ad
# ...                                          ...          ...
# 126634            task-oriented-dialogue-systems      kvret-1
# 126635            task-oriented-dialogue-systems      kvret-1
# 126636            task-oriented-dialogue-systems      kvret-1
# 126637            task-oriented-dialogue-systems      kvret-1
# 126638            task-oriented-dialogue-systems      kvret-1
#
#                     Metric   Value             Model  \
# 0       Segmentation AUPRO  0.9293      CPMF (2D+3D)
# 1          Detection AUROC  0.9515      CPMF (2D+3D)
# 2       Segmentation AUROC  0.9781      CPMF (2D+3D)
# 3       Segmentation AUPRO  0.9230         CPMF (3D)
# 4          Detection AUROC  0.8304         CPMF (3D)
# ...                    ...     ...               ...
# 126634                BLEU    13.2  KV Retrieval Net
# 126635           Entity F1    37.8              THPN
# 126636                BLEU    12.8              THPN
# 126637           Entity F1    33.4           Mem2Seq
# 126638                BLEU    12.6           Mem2Seq
#
#                                                  Paper        Date
# 0          complementary-pseudo-multimodal-feature-for  2023-03-23
# 1          complementary-pseudo-multimodal-feature-for  2023-03-23
# 2          complementary-pseudo-multimodal-feature-for  2023-03-23
# 3          complementary-pseudo-multimodal-feature-for  2023-03-23
# 4          complementary-pseudo-multimodal-feature-for  2023-03-23
# ...                                                ...         ...
# 126634           key-value-retrieval-networks-for-task  2017-05-15
# 126635  a-template-guided-hybrid-pointer-network-for-1  2021-08-01
# 126636  a-template-guided-hybrid-pointer-network-for-1  2021-08-01
# 126637     mem2seq-effectively-incorporating-knowledge  2018-04-23
# 126638     mem2seq-effectively-incorporating-knowledge  2018-04-23
#
# [126639 rows x 7 columns]

# %%
# Check for NaN values in both dataframes

print("Tasks DataFrame:")
print(tasks_df.isnull().sum())

print("\nEvaluations DataFrame:")
print(evaluations_df.isnull().sum())
# Out:
# Tasks DataFrame:
# area              0
# id                0
# name              0
# description    1565
# children       1602
# parents          50
# num_evals         0
# dtype: int64
#
# Evaluations DataFrame:
# Task           0
# Dataset        0
# Metric         0
# Value        478
# Model          0
# Paper      14537
# Date         987
# dtype: int64

# %%
# remove rows with NaN values in "Value" col of evaluations_df
evaluations_df = evaluations_df.dropna(subset=['Value'])

# Save to CSV
evaluations_df.to_csv('../data/interim/evaluations_by_task.csv', index=False)
